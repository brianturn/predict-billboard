# %%
df_clean.head(2)
len(df_clean)
# Out:
# 7143

# %%
df_clean['key'].value_counts()
# Out:
# 0.0     974
# 7.0     874
# 2.0     764
# 9.0     708
# 5.0     679
# 4.0     567
# 1.0     536
# 10.0    508
# 8.0     456
# 11.0    405
# 6.0     380
# 3.0     292
# Name: key, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(9,6))
plt.hist(df_clean['tempo'], bins=15, facecolor = 'gray', alpha=.8, edgecolor='black')
plt.title('Most Common Tempo of 7000 HOT 100 songs', fontsize=18)
plt.xlabel('Beats Per Minute', fontsize=16)
plt.ylabel('No. of Songs', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.savefig("tempo_histogram.png");
