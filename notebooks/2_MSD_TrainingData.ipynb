# %% [markdown]
# ### This notebook acquires song titles and audio features for 10,000 songs, a subset of the Million Song Dataset.

# %% [markdown]
# #### I initially set out to produce a project based on these features. With too many missing values from this dataset, I used the Spotify API to acquire audio features for the same 10,000 songs.

# %%
import os
import sys
import h5py
import numpy as np
import tables as tables
import glob
import time
import datetime

# %% [markdown]
# ### Instructions and functions for reading HDF5 files taken from here https://github.com/tbertinmahieux/MSongsDB

# %%
def get_all_files(basedir,ext='.h5') :
    """
    From a root directory, go through all subdirectories
    and find all files with the given extension.
    Return all absolute paths in a list.
    """
    allfiles = []
    for root, dirs, files in os.walk(basedir):
        files = glob.glob(os.path.join(root,'*'+ext))
        for f in files :
            allfiles.append( os.path.abspath(f) )
 
    return allfiles

# %%
allh5 = get_all_files('MillionSongSubset',ext='.h5')

# %%
def open_h5_file_read(h5filename):
    """
    Open an existing H5 in read mode.
    Same function as in hdf5_utils, here so we avoid one import
    """
    return tables.File(h5filename, mode='r')

def get_artist_name(h5,songidx=0):
    """
    Get artist name from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_name[songidx]

def get_title(h5,songidx=0):
    """
    Get title from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.title[songidx]

def get_num_songs(h5):
    """
    Return the number of songs contained in this h5 file, i.e. the number of rows
    for all basic informations like name, artist, ...
    """
    return h5.root.metadata.songs.nrows

def get_artist_familiarity(h5,songidx=0):
    """
    Get artist familiarity from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_familiarity[songidx]

def get_artist_hotttnesss(h5,songidx=0):
    """
    Get artist hotttnesss from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_hotttnesss[songidx]

def get_artist_id(h5,songidx=0):
    """
    Get artist id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_id[songidx]

def get_artist_mbid(h5,songidx=0):
    """
    Get artist musibrainz id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_mbid[songidx]

def get_artist_playmeid(h5,songidx=0):
    """
    Get artist playme id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_playmeid[songidx]

def get_artist_7digitalid(h5,songidx=0):
    """
    Get artist 7digital id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_7digitalid[songidx]

def get_artist_latitude(h5,songidx=0):
    """
    Get artist latitude from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_latitude[songidx]

def get_artist_longitude(h5,songidx=0):
    """
    Get artist longitude from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_longitude[songidx]

def get_artist_location(h5,songidx=0):
    """
    Get artist location from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.artist_location[songidx]

def get_release(h5,songidx=0):
    """
    Get release from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.release[songidx]

def get_release_7digitalid(h5,songidx=0):
    """
    Get release 7digital id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.release_7digitalid[songidx]

def get_song_id(h5,songidx=0):
    """
    Get song id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.song_id[songidx]

def get_song_hotttnesss(h5,songidx=0):
    """
    Get song hotttnesss from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.song_hotttnesss[songidx]

def get_track_7digitalid(h5,songidx=0):
    """
    Get track 7digital id from a HDF5 song file, by default the first song in it
    """
    return h5.root.metadata.songs.cols.track_7digitalid[songidx]

def get_similar_artists(h5,songidx=0):
    """
    Get similar artists array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.metadata.songs.nrows == songidx + 1:
        return h5.root.metadata.similar_artists[h5.root.metadata.songs.cols.idx_similar_artists[songidx]:]
    return h5.root.metadata.similar_artists[h5.root.metadata.songs.cols.idx_similar_artists[songidx]:
                                            h5.root.metadata.songs.cols.idx_similar_artists[songidx+1]]

def get_artist_terms(h5,songidx=0):
    """
    Get artist terms array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.metadata.songs.nrows == songidx + 1:
        return h5.root.metadata.artist_terms[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:]
    return h5.root.metadata.artist_terms[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:
                                            h5.root.metadata.songs.cols.idx_artist_terms[songidx+1]]

def get_artist_terms_freq(h5,songidx=0):
    """
    Get artist terms array frequencies. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.metadata.songs.nrows == songidx + 1:
        return h5.root.metadata.artist_terms_freq[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:]
    return h5.root.metadata.artist_terms_freq[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:
                                              h5.root.metadata.songs.cols.idx_artist_terms[songidx+1]]

def get_artist_terms_weight(h5,songidx=0):
    """
    Get artist terms array frequencies. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.metadata.songs.nrows == songidx + 1:
        return h5.root.metadata.artist_terms_weight[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:]
    return h5.root.metadata.artist_terms_weight[h5.root.metadata.songs.cols.idx_artist_terms[songidx]:
                                                h5.root.metadata.songs.cols.idx_artist_terms[songidx+1]]

def get_analysis_sample_rate(h5,songidx=0):
    """
    Get analysis sample rate from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.analysis_sample_rate[songidx]

def get_audio_md5(h5,songidx=0):
    """
    Get audio MD5 from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.audio_md5[songidx]

def get_danceability(h5,songidx=0):
    """
    Get danceability from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.danceability[songidx]

def get_duration(h5,songidx=0):
    """
    Get duration from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.duration[songidx]

def get_end_of_fade_in(h5,songidx=0):
    """
    Get end of fade in from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.end_of_fade_in[songidx]

def get_energy(h5,songidx=0):
    """
    Get energy from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.energy[songidx]

def get_key(h5,songidx=0):
    """
    Get key from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.key[songidx]

def get_key_confidence(h5,songidx=0):
    """
    Get key confidence from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.key_confidence[songidx]

def get_loudness(h5,songidx=0):
    """
    Get loudness from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.loudness[songidx]

def get_mode(h5,songidx=0):
    """
    Get mode from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.mode[songidx]

def get_mode_confidence(h5,songidx=0):
    """
    Get mode confidence from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.mode_confidence[songidx]

def get_start_of_fade_out(h5,songidx=0):
    """
    Get start of fade out from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.start_of_fade_out[songidx]

def get_tempo(h5,songidx=0):
    """
    Get tempo from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.tempo[songidx]

def get_time_signature(h5,songidx=0):
    """
    Get signature from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.time_signature[songidx]

def get_time_signature_confidence(h5,songidx=0):
    """
    Get signature confidence from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.time_signature_confidence[songidx]

def get_track_id(h5,songidx=0):
    """
    Get track id from a HDF5 song file, by default the first song in it
    """
    return h5.root.analysis.songs.cols.track_id[songidx]

def get_segments_start(h5,songidx=0):
    """
    Get segments start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_start[h5.root.analysis.songs.cols.idx_segments_start[songidx]:]
    return h5.root.analysis.segments_start[h5.root.analysis.songs.cols.idx_segments_start[songidx]:
                                           h5.root.analysis.songs.cols.idx_segments_start[songidx+1]]
    
def get_segments_confidence(h5,songidx=0):
    """
    Get segments confidence array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_confidence[h5.root.analysis.songs.cols.idx_segments_confidence[songidx]:]
    return h5.root.analysis.segments_confidence[h5.root.analysis.songs.cols.idx_segments_confidence[songidx]:
                                                h5.root.analysis.songs.cols.idx_segments_confidence[songidx+1]]

def get_segments_pitches(h5,songidx=0):
    """
    Get segments pitches array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_pitches[h5.root.analysis.songs.cols.idx_segments_pitches[songidx]:,:]
    return h5.root.analysis.segments_pitches[h5.root.analysis.songs.cols.idx_segments_pitches[songidx]:
                                             h5.root.analysis.songs.cols.idx_segments_pitches[songidx+1],:]

def get_segments_timbre(h5,songidx=0):
    """
    Get segments timbre array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_timbre[h5.root.analysis.songs.cols.idx_segments_timbre[songidx]:,:]
    return h5.root.analysis.segments_timbre[h5.root.analysis.songs.cols.idx_segments_timbre[songidx]:
                                            h5.root.analysis.songs.cols.idx_segments_timbre[songidx+1],:]

def get_segments_loudness_max(h5,songidx=0):
    """
    Get segments loudness max array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_loudness_max[h5.root.analysis.songs.cols.idx_segments_loudness_max[songidx]:]
    return h5.root.analysis.segments_loudness_max[h5.root.analysis.songs.cols.idx_segments_loudness_max[songidx]:
                                                  h5.root.analysis.songs.cols.idx_segments_loudness_max[songidx+1]]

def get_segments_loudness_max_time(h5,songidx=0):
    """
    Get segments loudness max time array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_loudness_max_time[h5.root.analysis.songs.cols.idx_segments_loudness_max_time[songidx]:]
    return h5.root.analysis.segments_loudness_max_time[h5.root.analysis.songs.cols.idx_segments_loudness_max_time[songidx]:
                                                       h5.root.analysis.songs.cols.idx_segments_loudness_max_time[songidx+1]]

def get_segments_loudness_start(h5,songidx=0):
    """
    Get segments loudness start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.segments_loudness_start[h5.root.analysis.songs.cols.idx_segments_loudness_start[songidx]:]
    return h5.root.analysis.segments_loudness_start[h5.root.analysis.songs.cols.idx_segments_loudness_start[songidx]:
                                                    h5.root.analysis.songs.cols.idx_segments_loudness_start[songidx+1]]

def get_sections_start(h5,songidx=0):
    """
    Get sections start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.sections_start[h5.root.analysis.songs.cols.idx_sections_start[songidx]:]
    return h5.root.analysis.sections_start[h5.root.analysis.songs.cols.idx_sections_start[songidx]:
                                           h5.root.analysis.songs.cols.idx_sections_start[songidx+1]]

def get_sections_confidence(h5,songidx=0):
    """
    Get sections confidence array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.sections_confidence[h5.root.analysis.songs.cols.idx_sections_confidence[songidx]:]
    return h5.root.analysis.sections_confidence[h5.root.analysis.songs.cols.idx_sections_confidence[songidx]:
                                                h5.root.analysis.songs.cols.idx_sections_confidence[songidx+1]]

def get_beats_start(h5,songidx=0):
    """
    Get beats start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.beats_start[h5.root.analysis.songs.cols.idx_beats_start[songidx]:]
    return h5.root.analysis.beats_start[h5.root.analysis.songs.cols.idx_beats_start[songidx]:
                                        h5.root.analysis.songs.cols.idx_beats_start[songidx+1]]

def get_beats_confidence(h5,songidx=0):
    """
    Get beats confidence array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.beats_confidence[h5.root.analysis.songs.cols.idx_beats_confidence[songidx]:]
    return h5.root.analysis.beats_confidence[h5.root.analysis.songs.cols.idx_beats_confidence[songidx]:
                                             h5.root.analysis.songs.cols.idx_beats_confidence[songidx+1]]

def get_bars_start(h5,songidx=0):
    """
    Get bars start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.bars_start[h5.root.analysis.songs.cols.idx_bars_start[songidx]:]
    return h5.root.analysis.bars_start[h5.root.analysis.songs.cols.idx_bars_start[songidx]:
                                       h5.root.analysis.songs.cols.idx_bars_start[songidx+1]]

def get_bars_confidence(h5,songidx=0):
    """
    Get bars start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.bars_confidence[h5.root.analysis.songs.cols.idx_bars_confidence[songidx]:]
    return h5.root.analysis.bars_confidence[h5.root.analysis.songs.cols.idx_bars_confidence[songidx]:
                                            h5.root.analysis.songs.cols.idx_bars_confidence[songidx+1]]

def get_tatums_start(h5,songidx=0):
    """
    Get tatums start array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.tatums_start[h5.root.analysis.songs.cols.idx_tatums_start[songidx]:]
    return h5.root.analysis.tatums_start[h5.root.analysis.songs.cols.idx_tatums_start[songidx]:
                                         h5.root.analysis.songs.cols.idx_tatums_start[songidx+1]]

def get_tatums_confidence(h5,songidx=0):
    """
    Get tatums confidence array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.analysis.songs.nrows == songidx + 1:
        return h5.root.analysis.tatums_confidence[h5.root.analysis.songs.cols.idx_tatums_confidence[songidx]:]
    return h5.root.analysis.tatums_confidence[h5.root.analysis.songs.cols.idx_tatums_confidence[songidx]:
                                              h5.root.analysis.songs.cols.idx_tatums_confidence[songidx+1]]

def get_artist_mbtags(h5,songidx=0):
    """
    Get artist musicbrainz tag array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.musicbrainz.songs.nrows == songidx + 1:
        return h5.root.musicbrainz.artist_mbtags[h5.root.musicbrainz.songs.cols.idx_artist_mbtags[songidx]:]
    return h5.root.musicbrainz.artist_mbtags[h5.root.metadata.songs.cols.idx_artist_mbtags[songidx]:
                                             h5.root.metadata.songs.cols.idx_artist_mbtags[songidx+1]]

def get_artist_mbtags_count(h5,songidx=0):
    """
    Get artist musicbrainz tag count array. Takes care of the proper indexing if we are in aggregate
    file. By default, return the array for the first song in the h5 file.
    To get a regular numpy ndarray, cast the result to: numpy.array( )
    """
    if h5.root.musicbrainz.songs.nrows == songidx + 1:
        return h5.root.musicbrainz.artist_mbtags_count[h5.root.musicbrainz.songs.cols.idx_artist_mbtags[songidx]:]
    return h5.root.musicbrainz.artist_mbtags_count[h5.root.metadata.songs.cols.idx_artist_mbtags[songidx]:
                                                   h5.root.metadata.songs.cols.idx_artist_mbtags[songidx+1]]

def get_year(h5,songidx=0):
    """
    Get release year from a HDF5 song file, by default the first song in it
    """
    return h5.root.musicbrainz.songs.cols.year[songidx]

# %% [markdown]
# ### Loop through functions and zip data to a Pandas dataframe

# %%
headers = ['artist', 'title', 'familiarity', 'hotttnesss_artist', 'artist_id',
                              'mbid', 'playmeid', 'seven_digital', 'latitude', 'longitude', 'location', 'release', 'song_id', 'hotttness_song',
                                  'seven_trackid', 'sample_rate_analysis', 'danceability', 'duration', 'end_of_fade',
                                  'energy', 'key', 'key_confidence', 'loudness', 'mode', 'mode_confidence', 'start_fade', 'tempo', 'time_signature',
                                  'time_signature_confidence', 'year']

song_data = []

for f in allh5:
    filename = open_h5_file_read(f)
    artist = get_artist_name(filename)
    title = get_title(filename)
    familiarity = get_artist_familiarity(filename)
    hotttnesss_artist = get_artist_hotttnesss(filename)
    artist_id = get_artist_id(filename)
    mbid = get_artist_mbid(filename)
    playmeid = get_artist_playmeid(filename)
    seven_digital = get_artist_7digitalid(filename)
    latitude = get_artist_latitude(filename)
    longitude = get_artist_longitude(filename)
    location = get_artist_location(filename)
    release = get_release(filename)
    song_id = get_song_id(filename)
    hotttness_song = get_song_hotttnesss(filename)
    seven_trackid = get_track_7digitalid(filename)
    #similar_artists = get_similar_artists(filename)
    sample_rate_analysis = get_analysis_sample_rate(filename)
    danceability = get_danceability(filename)
    duration = get_duration(filename)
    end_of_fade = get_end_of_fade_in(filename)
    energy = get_energy(filename)
    key = get_key(filename)
    key_confidence = get_key_confidence(filename)
    loudness = get_loudness(filename)
    mode = get_mode(filename)
    mode_confidence = get_mode_confidence(filename)
    start_fade = get_start_of_fade_out(filename)
    tempo = get_tempo(filename)
    time_signature = get_time_signature(filename)
    time_signature_confidence = get_time_signature_confidence(filename)
    #artist_mbtags = get_artist_mbtags(filename)
    #mbtags_count = get_artist_mbtags_count(filename)
    year = get_year(filename)
    filename.close()
    
    data_dict = dict(zip(headers, [artist, title, familiarity, hotttnesss_artist, artist_id,
                              mbid, playmeid, seven_digital, latitude, longitude, location, release, song_id, hotttness_song,
                                  seven_trackid, sample_rate_analysis, danceability, duration, end_of_fade,
                                  energy, key, key_confidence, loudness, mode, mode_confidence, start_fade, tempo, time_signature,
                                  time_signature_confidence, year]))

    song_data.append(data_dict)

song_data
# Out:
# [{'artist': b'Mastodon',
#   'artist_id': b'ARMQHX71187B9890D3',
#   'danceability': 0.0,
#   'duration': 280.21505999999999,
#   'end_of_fade': 0.23799999999999999,
#   'energy': 0.0,
#   'familiarity': 0.78046174877704066,
#   'hotttness_song': 0.59764079771477685,
#   'hotttnesss_artist': 0.57427473051685607,
#   'key': 5,
#   'key_confidence': 0.55500000000000005,
#   'latitude': nan,
#   'location': b'Atlanta, GA',
#   'longitude': nan,
#   'loudness': -3.306,
#   'mbid': b'bc5e2ad6-0a4a-4d90-b911-e9a7e6861727',
#   'mode': 1,
#   'mode_confidence': 0.5,
#   'playmeid': -1,
#   'release': b'Call of the Mastodon',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 29785,
#   'seven_trackid': 2442524,
#   'song_id': b'SOVLGJY12A8C13FBED',
#   'start_fade': 275.52800000000002,
#   'tempo': 173.20500000000001,
#   'time_signature': 5,
#   'time_signature_confidence': 0.12,
#   'title': b'Deep Sea Creature',
#   'year': 2001},
#  {'artist': b'Casual',
#   'artist_id': b'ARD7TVE1187B99BFB1',
#   'danceability': 0.0,
#   'duration': 218.93179000000001,
#   'end_of_fade': 0.247,
#   'energy': 0.0,
#   'familiarity': 0.58179376584502807,
#   'hotttness_song': 0.60211998990575477,
#   'hotttnesss_artist': 0.40199754336428362,
#   'key': 1,
#   'key_confidence': 0.73599999999999999,
#   'latitude': nan,
#   'location': b'California - LA',
#   'longitude': nan,
#   'loudness': -11.196999999999999,
#   'mbid': b'e77e51a5-4761-45b3-9847-2051f811e366',
#   'mode': 0,
#   'mode_confidence': 0.63600000000000001,
#   'playmeid': 4479,
#   'release': b'Fear Itself',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 165270,
#   'seven_trackid': 3401791,
#   'song_id': b'SOMZWCG12A8C13C480',
#   'start_fade': 218.93199999999999,
#   'tempo': 92.197999999999993,
#   'time_signature': 4,
#   'time_signature_confidence': 0.77800000000000002,
#   'title': b"I Didn't Mean To",
#   'year': 0},
#  {'artist': b'The Box Tops',
#   'artist_id': b'ARMJAGH1187FB546F3',
#   'danceability': 0.0,
#   'duration': 148.03546,
#   'end_of_fade': 0.14799999999999999,
#   'energy': 0.0,
#   'familiarity': 0.63063003758980773,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.41749964497097841,
#   'key': 6,
#   'key_confidence': 0.16900000000000001,
#   'latitude': 35.149679999999996,
#   'location': b'Memphis, TN',
#   'longitude': -90.048919999999995,
#   'loudness': -9.843,
#   'mbid': b'1c78ab62-db33-4433-8d0b-7c8dcf1849c2',
#   'mode': 0,
#   'mode_confidence': 0.42999999999999999,
#   'playmeid': 22066,
#   'release': b'Dimensions',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 1998,
#   'seven_trackid': 3400270,
#   'song_id': b'SOCIWDW12A8C13D406',
#   'start_fade': 137.91499999999999,
#   'tempo': 121.274,
#   'time_signature': 4,
#   'time_signature_confidence': 0.38400000000000001,
#   'title': b'Soul Deep',
#   'year': 1969},
#  {'artist': b'Sonora Santanera',
#   'artist_id': b'ARKRRTF1187B9984DA',
#   'danceability': 0.0,
#   'duration': 177.47546,
#   'end_of_fade': 0.28199999999999997,
#   'energy': 0.0,
#   'familiarity': 0.48735679092814771,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.34342837829688244,
#   'key': 8,
#   'key_confidence': 0.64300000000000002,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.6890000000000001,
#   'mbid': b'7a273984-edd9-4451-9c4d-39b38f05ebcd',
#   'mode': 1,
#   'mode_confidence': 0.56499999999999995,
#   'playmeid': 13951,
#   'release': b'Las Numero 1 De La Sonora Santanera',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 290021,
#   'seven_trackid': 5703798,
#   'song_id': b'SOXVLOJ12AB0189215',
#   'start_fade': 172.304,
#   'tempo': 100.06999999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Amor De Cabaret',
#   'year': 0},
#  {'artist': b'Adam Ant',
#   'artist_id': b'AR7G5I41187FB4CE6C',
#   'danceability': 0.0,
#   'duration': 233.40362999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.63038233414678058,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.45423115657062052,
#   'key': 0,
#   'key_confidence': 0.751,
#   'latitude': nan,
#   'location': b'London, England',
#   'longitude': nan,
#   'loudness': -9.0129999999999999,
#   'mbid': b'e188a520-9cb7-4f73-a3d7-2f70c6538e92',
#   'mode': 1,
#   'mode_confidence': 0.749,
#   'playmeid': 12697,
#   'release': b'Friend Or Foe',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 19072,
#   'seven_trackid': 3226795,
#   'song_id': b'SONHOTT12A8C13493C',
#   'start_fade': 217.124,
#   'tempo': 119.29300000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Something Girls',
#   'year': 1982},
#  {'artist': b'Gob',
#   'artist_id': b'ARXR32B1187FB57099',
#   'danceability': 0.0,
#   'duration': 209.60607999999999,
#   'end_of_fade': 0.066000000000000003,
#   'energy': 0.0,
#   'familiarity': 0.65104566083179471,
#   'hotttness_song': 0.6045007385888197,
#   'hotttnesss_artist': 0.40172368550367865,
#   'key': 2,
#   'key_confidence': 0.091999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -4.5010000000000003,
#   'mbid': b'c6903a2e-063c-4f91-a284-17b8f421be7b',
#   'mode': 1,
#   'mode_confidence': 0.371,
#   'playmeid': 8355,
#   'release': b'Muertos Vivos',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 30973,
#   'seven_trackid': 6795666,
#   'song_id': b'SOFSOCN12A8C143F5D',
#   'start_fade': 198.69900000000001,
#   'tempo': 129.738,
#   'time_signature': 4,
#   'time_signature_confidence': 0.56200000000000006,
#   'title': b'Face the Ashes',
#   'year': 2007},
#  {'artist': b'Jeff And Sheri Easter',
#   'artist_id': b'ARKFYS91187B98E58F',
#   'danceability': 0.0,
#   'duration': 267.70240000000001,
#   'end_of_fade': 2.2639999999999998,
#   'energy': 0.0,
#   'familiarity': 0.53529273551181966,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.38547055055582102,
#   'key': 5,
#   'key_confidence': 0.63500000000000001,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.3230000000000004,
#   'mbid': b'79c403f9-5467-4f23-8426-9ca3fc60a115',
#   'mode': 1,
#   'mode_confidence': 0.55700000000000005,
#   'playmeid': 63801,
#   'release': b'Ordinary Day',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 432935,
#   'seven_trackid': 444964,
#   'song_id': b'SOYMRWW12A6D4FAB14',
#   'start_fade': 254.27000000000001,
#   'tempo': 147.78200000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.45400000000000001,
#   'title': b'The Moon And I (Ordinary Day Album Version)',
#   'year': 0},
#  {'artist': b'Rated R',
#   'artist_id': b'ARD0S291187B9B7BF5',
#   'danceability': 0.0,
#   'duration': 114.78158999999999,
#   'end_of_fade': 0.096000000000000002,
#   'energy': 0.0,
#   'familiarity': 0.55649560191295722,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.26194117738084738,
#   'key': 1,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'Ohio',
#   'longitude': nan,
#   'loudness': -17.302,
#   'mbid': b'56503d6d-094e-4c28-ae3d-04cc748ade5b',
#   'mode': 1,
#   'mode_confidence': 0.0,
#   'playmeid': -1,
#   'release': b'Da Ghetto Psychic',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 17970,
#   'seven_trackid': 276593,
#   'song_id': b'SOMJBYD12A6D4F8557',
#   'start_fade': 114.782,
#   'tempo': 111.78700000000001,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Keepin It Real (Skit)',
#   'year': 0},
#  {'artist': b'Tweeterfriendly Music',
#   'artist_id': b'AR10USD1187B99F3F1',
#   'danceability': 0.0,
#   'duration': 189.57015999999999,
#   'end_of_fade': 0.31900000000000001,
#   'energy': 0.0,
#   'familiarity': 0.80113644699668729,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.60550713569057524,
#   'key': 4,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'Burlington, Ontario, Canada',
#   'longitude': nan,
#   'loudness': -11.641999999999999,
#   'mbid': b'd89de379-665d-425c-b2e9-41b95d1edb36',
#   'mode': 0,
#   'mode_confidence': 0.16,
#   'playmeid': -1,
#   'release': b'Gin & Phonic',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 21128,
#   'seven_trackid': 90004,
#   'song_id': b'SOHKNRJ12A6701D1F8',
#   'start_fade': 181.023,
#   'tempo': 101.43000000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.40799999999999997,
#   'title': b'Drop of Rain',
#   'year': 0},
#  {'artist': b'Planet P Project',
#   'artist_id': b'AR8ZCNI1187B9A069B',
#   'danceability': 0.0,
#   'duration': 269.81832000000003,
#   'end_of_fade': 5.2999999999999998,
#   'energy': 0.0,
#   'familiarity': 0.42666785706940524,
#   'hotttness_song': 0.26586104921065007,
#   'hotttnesss_artist': 0.33227574659906806,
#   'key': 4,
#   'key_confidence': 0.71699999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -13.496,
#   'mbid': b'19d232b9-b4d7-4dc8-b259-bf65efb655b1',
#   'mode': 1,
#   'mode_confidence': 0.65200000000000002,
#   'playmeid': -1,
#   'release': b'Pink World',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 276891,
#   'seven_trackid': 3996579,
#   'song_id': b'SOIAZJW12AB01853F1',
#   'start_fade': 258.99000000000001,
#   'tempo': 86.643000000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.48699999999999999,
#   'title': b'Pink World',
#   'year': 1984},
#  {'artist': b'Clp',
#   'artist_id': b'ARNTLGG11E2835DDB9',
#   'danceability': 0.0,
#   'duration': 266.39627999999999,
#   'end_of_fade': 0.084000000000000005,
#   'energy': 0.0,
#   'familiarity': 0.55051369784821369,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42270564102939107,
#   'key': 7,
#   'key_confidence': 0.052999999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.6970000000000001,
#   'mbid': b'4d96f7d0-2f0e-4e92-ba70-a405f96f8cec',
#   'mode': 0,
#   'mode_confidence': 0.47299999999999998,
#   'playmeid': -1,
#   'release': b'Superinstrumental',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 242273,
#   'seven_trackid': 7684249,
#   'song_id': b'SOUDSGM12AC9618304',
#   'start_fade': 261.74700000000001,
#   'tempo': 114.041,
#   'time_signature': 4,
#   'time_signature_confidence': 0.878,
#   'title': b'Insatiable (Instrumental Version)',
#   'year': 0},
#  {'artist': b'JennyAnyKind',
#   'artist_id': b'ARGSJW91187B9B1D6B',
#   'danceability': 0.0,
#   'duration': 218.77506,
#   'end_of_fade': 2.125,
#   'energy': 0.0,
#   'familiarity': 0.3600311664643514,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.29626895431146333,
#   'key': 5,
#   'key_confidence': 0.35399999999999998,
#   'latitude': 35.219619999999999,
#   'location': b'North Carolina',
#   'longitude': -80.019549999999995,
#   'loudness': -10.021000000000001,
#   'mbid': b'eb722df4-372e-4742-8586-f7ff658012d6',
#   'mode': 0,
#   'mode_confidence': 0.48499999999999999,
#   'playmeid': -1,
#   'release': b'I Need You',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 60488,
#   'seven_trackid': 5967937,
#   'song_id': b'SOQHXMF12AB0182363',
#   'start_fade': 207.012,
#   'tempo': 146.76499999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Young Boy Blues',
#   'year': 0},
#  {'artist': b'Wayne Watson',
#   'artist_id': b'ARC43071187B990240',
#   'danceability': 0.0,
#   'duration': 245.21098000000001,
#   'end_of_fade': 0.35699999999999998,
#   'energy': 0.0,
#   'familiarity': 0.54515929560086318,
#   'hotttness_song': 0.26586104921065007,
#   'hotttnesss_artist': 0.35155586118563925,
#   'key': 7,
#   'key_confidence': 0.070000000000000007,
#   'latitude': nan,
#   'location': b'Wisner, LA',
#   'longitude': nan,
#   'loudness': -7.5449999999999999,
#   'mbid': b'001a1d90-56dc-4992-bd7d-970ecd7105d0',
#   'mode': 1,
#   'mode_confidence': 0.68600000000000005,
#   'playmeid': 17334,
#   'release': b'The Way Home',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 4923,
#   'seven_trackid': 1735859,
#   'song_id': b'SOKEJEJ12A8C13E0D0',
#   'start_fade': 227.47999999999999,
#   'tempo': 117.97499999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.83499999999999996,
#   'title': b'The Urgency (LP Version)',
#   'year': 0},
#  {'artist': b'Andy Andy',
#   'artist_id': b'ARL7K851187B99ACD2',
#   'danceability': 0.0,
#   'duration': 226.35057,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.57750897432529769,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.37948217028046749,
#   'key': 9,
#   'key_confidence': 0.20499999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.6319999999999997,
#   'mbid': b'572d6bb7-58cc-4a96-8e5c-58eae4739190',
#   'mode': 1,
#   'mode_confidence': 0.30499999999999999,
#   'playmeid': 14303,
#   'release': b'Placer & Castigo',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 88523,
#   'seven_trackid': 6381162,
#   'song_id': b'SOMUYGI12AB0188633',
#   'start_fade': 221.553,
#   'tempo': 130.03999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'La Culpa',
#   'year': 0},
#  {'artist': b'Bob Azzam',
#   'artist_id': b'ARHHO3O1187B989413',
#   'danceability': 0.0,
#   'duration': 191.84280999999999,
#   'end_of_fade': 0.38,
#   'energy': 0.0,
#   'familiarity': 0.085512047108578793,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.25193652476242323,
#   'key': 10,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -7.75,
#   'mbid': b'e870caaf-3650-4ed8-9ca1-1ac36419abb0',
#   'mode': 0,
#   'mode_confidence': 0.19800000000000001,
#   'playmeid': -1,
#   'release': b'Arrivederci',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 327171,
#   'seven_trackid': 9014963,
#   'song_id': b'SORAMLE12AB017C8B0',
#   'start_fade': 188.42400000000001,
#   'tempo': 137.334,
#   'time_signature': 1,
#   'time_signature_confidence': 0.31900000000000001,
#   'title': b'Auguri Cha Cha',
#   'year': 0},
#  {'artist': b'Lionel Richie',
#   'artist_id': b'ARIK43K1187B9AE54C',
#   'danceability': 0.0,
#   'duration': 307.38240000000002,
#   'end_of_fade': 0.61199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.77667585568455411,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.55307199146197528,
#   'key': 3,
#   'key_confidence': 0.52400000000000002,
#   'latitude': nan,
#   'location': b'Beverly Hills, CA',
#   'longitude': nan,
#   'loudness': -8.3460000000000001,
#   'mbid': b'3cb25fb2-5547-4b05-adec-1a5e37830d46',
#   'mode': 1,
#   'mode_confidence': 0.53300000000000003,
#   'playmeid': -1,
#   'release': b'Dancing On The Ceiling',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 237,
#   'seven_trackid': 276438,
#   'song_id': b'SOBONFF12A6D4F84D8',
#   'start_fade': 296.65800000000002,
#   'tempo': 125.197,
#   'time_signature': 3,
#   'time_signature_confidence': 0.21099999999999999,
#   'title': b'Tonight Will Be Alright',
#   'year': 1986},
#  {'artist': b'Blue Rodeo',
#   'artist_id': b'ARD842G1187B997376',
#   'danceability': 0.0,
#   'duration': 491.12770999999998,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.63642364495006976,
#   'hotttness_song': 0.40511572169138649,
#   'hotttnesss_artist': 0.44793548047950221,
#   'key': 7,
#   'key_confidence': 1.0,
#   'latitude': 43.648560000000003,
#   'location': b'Toronto, Ontario, Canada',
#   'longitude': -79.385329999999996,
#   'loudness': -8.5760000000000005,
#   'mbid': b'6b52e1be-f27a-433c-b51a-3f2d63abc2ba',
#   'mode': 1,
#   'mode_confidence': 0.82899999999999996,
#   'playmeid': -1,
#   'release': b'Outskirts',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 3950,
#   'seven_trackid': 1399936,
#   'song_id': b'SOHUOAP12A8AE488E9',
#   'start_fade': 486.03399999999999,
#   'tempo': 119.82599999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.75600000000000001,
#   'title': b'Floating',
#   'year': 1987},
#  {'artist': b'Richard Souther',
#   'artist_id': b'ARIG6O41187B988BDD',
#   'danceability': 0.0,
#   'duration': 228.59710000000001,
#   'end_of_fade': 0.223,
#   'energy': 0.0,
#   'familiarity': 0.4199431484349393,
#   'hotttness_song': 0.33470654906922059,
#   'hotttnesss_artist': 0.33080635685585685,
#   'key': 8,
#   'key_confidence': 0.041000000000000002,
#   'latitude': 37.167929999999998,
#   'location': b'United States',
#   'longitude': -95.845020000000005,
#   'loudness': -16.109999999999999,
#   'mbid': b'9f6413ef-4320-4833-87be-3ad1d3bf238f',
#   'mode': 1,
#   'mode_confidence': 0.51600000000000001,
#   'playmeid': 18135,
#   'release': b'Cross Currents',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 24687,
#   'seven_trackid': 1560940,
#   'song_id': b'SOUQQEA12A8C134B1B',
#   'start_fade': 217.42599999999999,
#   'tempo': 127.756,
#   'time_signature': 5,
#   'time_signature_confidence': 0.57899999999999996,
#   'title': b'High Tide',
#   'year': 0},
#  {'artist': b'Faiz Ali Faiz',
#   'artist_id': b'AR1ZHYZ1187FB3C717',
#   'danceability': 0.0,
#   'duration': 599.24852999999996,
#   'end_of_fade': 1.1930000000000001,
#   'energy': 0.0,
#   'familiarity': 0.36328057110998851,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.30667609347902947,
#   'key': 6,
#   'key_confidence': 0.059999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -8.032,
#   'mbid': b'762e2728-f093-4548-8f36-f4580d83e207',
#   'mode': 1,
#   'mode_confidence': 0.34599999999999997,
#   'playmeid': -1,
#   'release': b'Panjtan Ka Ghulam',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 248913,
#   'seven_trackid': 5916675,
#   'song_id': b'SOILPQQ12AB017E82A',
#   'start_fade': 591.99900000000002,
#   'tempo': 99.272999999999996,
#   'time_signature': 4,
#   'time_signature_confidence': 0.158,
#   'title': b'Sohna Nee Sohna Data',
#   'year': 0},
#  {'artist': b'Tesla',
#   'artist_id': b'ARYKCQI1187FB3B18F',
#   'danceability': 0.0,
#   'duration': 290.29831999999999,
#   'end_of_fade': 0.14499999999999999,
#   'energy': 0.0,
#   'familiarity': 0.70719976383793626,
#   'hotttness_song': 0.68413619122949032,
#   'hotttnesss_artist': 0.51346328970215582,
#   'key': 7,
#   'key_confidence': 0.72499999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -5.2709999999999999,
#   'mbid': b'eeacb319-8d4c-48e0-80a0-944e71c375bf',
#   'mode': 1,
#   'mode_confidence': 0.75600000000000001,
#   'playmeid': 7536,
#   'release': b'Gold',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 1396,
#   'seven_trackid': 4143071,
#   'song_id': b'SOXLBJT12A8C140925',
#   'start_fade': 285.60500000000002,
#   'tempo': 150.06200000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.93100000000000005,
#   'title': b'Caught In A Dream',
#   'year': 2004},
#  {'artist': b'lextrical',
#   'artist_id': b'ARNPAGP1241B9C7FD4',
#   'danceability': 0.0,
#   'duration': 165.69424000000001,
#   'end_of_fade': 0.16200000000000001,
#   'energy': 0.0,
#   'familiarity': 0.32031437017067216,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.0,
#   'key': 7,
#   'key_confidence': 0.010999999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.7869999999999999,
#   'mbid': b'',
#   'mode': 1,
#   'mode_confidence': 0.56799999999999995,
#   'playmeid': -1,
#   'release': b'Whatever Happened To Boredom?',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 399889,
#   'seven_trackid': 5991843,
#   'song_id': b'SOZVMJI12AB01808AF',
#   'start_fade': 157.39099999999999,
#   'tempo': 138.33099999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.127,
#   'title': b'Synthetic Dream',
#   'year': 0},
#  {'artist': b'Jimmy Wakely',
#   'artist_id': b'ARQGYP71187FB44566',
#   'danceability': 0.0,
#   'duration': 151.84934000000001,
#   'end_of_fade': 2.827,
#   'energy': 0.0,
#   'familiarity': 0.39413853984589253,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.29153972708877773,
#   'key': 1,
#   'key_confidence': 0.79900000000000004,
#   'latitude': 34.31109,
#   'location': b'Mineola, AR',
#   'longitude': -94.029780000000002,
#   'loudness': -15.221,
#   'mbid': b'0b8f67b3-b1d8-4d7a-8317-9d2e7e1cb277',
#   'mode': 1,
#   'mode_confidence': 0.71599999999999997,
#   'playmeid': 156926,
#   'release': b'1942-1952 Jimmy Wakely',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 34818,
#   'seven_trackid': 6721979,
#   'song_id': b'SOWTBJW12AC468AC6E',
#   'start_fade': 146.19900000000001,
#   'tempo': 86.186000000000007,
#   'time_signature': 3,
#   'time_signature_confidence': 0.92900000000000005,
#   'title': b'Broken-Down Merry-Go-Round',
#   'year': 0},
#  {'artist': b'Alice Stuart',
#   'artist_id': b'ARI3BMM1187FB4255E',
#   'danceability': 0.0,
#   'duration': 220.78648999999999,
#   'end_of_fade': 0.20599999999999999,
#   'energy': 0.0,
#   'familiarity': 0.48981626898204073,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.32855301501801859,
#   'key': 11,
#   'key_confidence': 0.80900000000000005,
#   'latitude': 38.899099999999997,
#   'location': b'Washington',
#   'longitude': -77.028999999999996,
#   'loudness': -8.5139999999999993,
#   'mbid': b'c5bca5a8-1357-4f4c-8544-b36c814ff6d6',
#   'mode': 1,
#   'mode_confidence': 0.52100000000000002,
#   'playmeid': -1,
#   'release': b'All The Good Times',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 185559,
#   'seven_trackid': 3006504,
#   'song_id': b'SOBEBDG12A58A76D60',
#   'start_fade': 207.65600000000001,
#   'tempo': 110.38200000000001,
#   'time_signature': 1,
#   'time_signature_confidence': 0.192,
#   'title': b'Kassie Jones',
#   'year': 0},
#  {'artist': b'Elena',
#   'artist_id': b'AR5KOSW1187FB35FF4',
#   'danceability': 0.0,
#   'duration': 269.58321999999998,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.67742046522622978,
#   'hotttness_song': 0.31356211424793418,
#   'hotttnesss_artist': 0.37825468551016656,
#   'key': 2,
#   'key_confidence': 0.59599999999999997,
#   'latitude': 49.803879999999999,
#   'location': b'Dubai UAE',
#   'longitude': 15.474909999999999,
#   'loudness': -8.0500000000000007,
#   'mbid': b'd3cc4c24-1b5b-4d71-bcc9-1940e0e3e9d3',
#   'mode': 1,
#   'mode_confidence': 0.66600000000000004,
#   'playmeid': 34776,
#   'release': b'Un cafe_ setanta matins',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 69720,
#   'seven_trackid': 4292004,
#   'song_id': b'SOZCTXZ12AB0182364',
#   'start_fade': 256.16800000000001,
#   'tempo': 111.874,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Setanta matins',
#   'year': 0},
#  {'artist': b'The Dillinger Escape Plan',
#   'artist_id': b'ARMAC4T1187FB3FA4C',
#   'danceability': 0.0,
#   'duration': 207.77751000000001,
#   'end_of_fade': 0.060999999999999999,
#   'energy': 0.0,
#   'familiarity': 0.83996276815103699,
#   'hotttness_song': 0.66652784622970229,
#   'hotttnesss_artist': 0.54188897203364694,
#   'key': 7,
#   'key_confidence': 0.38100000000000001,
#   'latitude': 40.826239999999999,
#   'location': b'Morris Plains, NJ',
#   'longitude': -74.479950000000002,
#   'loudness': -4.2640000000000002,
#   'mbid': b'1bc41dff-5397-4c53-bb50-469d2c277197',
#   'mode': 1,
#   'mode_confidence': 0.45300000000000001,
#   'playmeid': 11414,
#   'release': b'Miss Machine',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 82239,
#   'seven_trackid': 2439720,
#   'song_id': b'SOBBUGU12A8C13E95D',
#   'start_fade': 204.696,
#   'tempo': 166.86199999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Setting Fire to Sleeping Giants',
#   'year': 2004},
#  {'artist': b'SUE THOMPSON',
#   'artist_id': b'AR47JEX1187B995D81',
#   'danceability': 0.0,
#   'duration': 124.86485,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.43541581815506936,
#   'hotttness_song': 0.49529362129216348,
#   'hotttnesss_artist': 0.3062422642462862,
#   'key': 10,
#   'key_confidence': 0.69699999999999995,
#   'latitude': 37.837209999999999,
#   'location': b'Nevada, MO',
#   'longitude': -94.358680000000007,
#   'loudness': -12.332000000000001,
#   'mbid': b'7994b392-4b14-4b06-b591-fd8b0ad65338',
#   'mode': 1,
#   'mode_confidence': 0.54100000000000004,
#   'playmeid': -1,
#   'release': b'Sue Thompson - Her Very Best',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 36525,
#   'seven_trackid': 7232396,
#   'song_id': b'SOBLGCN12AB0183212',
#   'start_fade': 115.73999999999999,
#   'tempo': 137.52199999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'James (Hold The Ladder Steady)',
#   'year': 1985},
#  {'artist': b'Five Bolt Main',
#   'artist_id': b'ARGIWFO1187B9B55B7',
#   'danceability': 0.0,
#   'duration': 225.09669,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.60906370003105015,
#   'hotttness_song': 0.37598430150044215,
#   'hotttnesss_artist': 0.3636513650591166,
#   'key': 7,
#   'key_confidence': 0.53000000000000003,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -5.9080000000000004,
#   'mbid': b'34f4bdc2-ed51-44da-af51-7e507d9d4721',
#   'mode': 1,
#   'mode_confidence': 0.51200000000000001,
#   'playmeid': -1,
#   'release': b'Live',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14773,
#   'seven_trackid': 488005,
#   'song_id': b'SOPSWQW12A6D4F8781',
#   'start_fade': 225.09700000000001,
#   'tempo': 164.672,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Made Like This (Live)',
#   'year': 0},
#  {'artist': b'Clp',
#   'artist_id': b'ARNTLGG11E2835DDB9',
#   'danceability': 0.0,
#   'duration': 338.31137999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.55051369784821369,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42270564102939107,
#   'key': 6,
#   'key_confidence': 0.68700000000000006,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.4859999999999998,
#   'mbid': b'4d96f7d0-2f0e-4e92-ba70-a405f96f8cec',
#   'mode': 0,
#   'mode_confidence': 0.48599999999999999,
#   'playmeid': -1,
#   'release': b'Strictly Confidential',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 242273,
#   'seven_trackid': 7448953,
#   'song_id': b'SOZQDIU12A58A7BCF6',
#   'start_fade': 338.31099999999998,
#   'tempo': 125.006,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Superconfidential',
#   'year': 0},
#  {'artist': b'Tim Wilson',
#   'artist_id': b'ARDNS031187B9924F0',
#   'danceability': 0.0,
#   'duration': 186.48770999999999,
#   'end_of_fade': 1.083,
#   'energy': 0.0,
#   'familiarity': 0.45979712883761042,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.34991261167456278,
#   'key': 5,
#   'key_confidence': 0.76200000000000001,
#   'latitude': 32.678280000000001,
#   'location': b'Georgia',
#   'longitude': -83.222949999999997,
#   'loudness': -4.516,
#   'mbid': b'e29641cc-3658-4886-89d7-3a146d2d3d75',
#   'mode': 1,
#   'mode_confidence': 0.53900000000000003,
#   'playmeid': 7570,
#   'release': b'The Real Twang Thang',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14504,
#   'seven_trackid': 1699837,
#   'song_id': b'SONYPOM12A8C13B2D7',
#   'start_fade': 175.46700000000001,
#   'tempo': 90.022000000000006,
#   'time_signature': 1,
#   'time_signature_confidence': 0.97099999999999997,
#   'title': b'I Think My Wife Is Running Around On Me (Taco Hell)',
#   'year': 2005},
#  {'artist': b'Willie Bobo',
#   'artist_id': b'AROUOZZ1187B9ABE51',
#   'danceability': 0.0,
#   'duration': 168.25424000000001,
#   'end_of_fade': 0.20000000000000001,
#   'energy': 0.0,
#   'familiarity': 0.58882710050180576,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.37967112474986731,
#   'key': 8,
#   'key_confidence': 0.81200000000000006,
#   'latitude': 40.79195,
#   'location': b'New York, NY [Spanish Harlem]',
#   'longitude': -73.945120000000003,
#   'loudness': -9.6159999999999997,
#   'mbid': b'dadec058-023e-498a-b1c7-776d03cc88ce',
#   'mode': 1,
#   'mode_confidence': 0.73599999999999999,
#   'playmeid': -1,
#   'release': b"Willie Bobo's Finest Hour",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 15815,
#   'seven_trackid': 618725,
#   'song_id': b'SOBZBAZ12A6D4F8742',
#   'start_fade': 161.88999999999999,
#   'tempo': 127.02500000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.79200000000000004,
#   'title': b'Spanish Grease',
#   'year': 1997},
#  {'artist': b'Faye Adams',
#   'artist_id': b'ARH4Z031187B9A71F2',
#   'danceability': 0.0,
#   'duration': 156.39465000000001,
#   'end_of_fade': 0.56200000000000006,
#   'energy': 0.0,
#   'familiarity': 0.39645525391729608,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.2992303679293693,
#   'key': 8,
#   'key_confidence': 0.56899999999999995,
#   'latitude': 40.731969999999997,
#   'location': b'Newark, NJ',
#   'longitude': -74.174180000000007,
#   'loudness': -18.050999999999998,
#   'mbid': b'8f2974e0-3647-48f6-86f8-603a2c5f31ae',
#   'mode': 1,
#   'mode_confidence': 0.495,
#   'playmeid': 70806,
#   'release': b'Shake A Hand',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 28882,
#   'seven_trackid': 5660441,
#   'song_id': b'SOVYKGO12AB0187199',
#   'start_fade': 150.63399999999999,
#   'tempo': 95.956999999999994,
#   'time_signature': 3,
#   'time_signature_confidence': 0.68899999999999995,
#   'title': b'Crazy Mixed Up World',
#   'year': 1961},
#  {'artist': b'Terry Callier',
#   'artist_id': b'ARB29H41187B98F0EF',
#   'danceability': 0.0,
#   'duration': 342.56934000000001,
#   'end_of_fade': 0.063,
#   'energy': 0.0,
#   'familiarity': 0.70682767130445823,
#   'hotttness_song': 0.41373983586010971,
#   'hotttnesss_artist': 0.4161730646266773,
#   'key': 6,
#   'key_confidence': 0.38100000000000001,
#   'latitude': 41.884149999999998,
#   'location': b'Chicago',
#   'longitude': -87.632409999999993,
#   'loudness': -11.939,
#   'mbid': b'44fd61e1-119c-479e-8301-8ac5c77148bf',
#   'mode': 1,
#   'mode_confidence': 0.53800000000000003,
#   'playmeid': 43725,
#   'release': b'Occasional Rain',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9947,
#   'seven_trackid': 2503960,
#   'song_id': b'SOGNCJP12A58A80271',
#   'start_fade': 333.154,
#   'tempo': 110.18899999999999,
#   'time_signature': 3,
#   'time_signature_confidence': 0.35299999999999998,
#   'title': b'Do You Finally Need A Friend',
#   'year': 1972},
#  {'artist': b'John Wesley',
#   'artist_id': b'AR1Y2PT1187FB5B9CE',
#   'danceability': 0.0,
#   'duration': 484.62322,
#   'end_of_fade': 28.172000000000001,
#   'energy': 0.0,
#   'familiarity': 0.56055798390381462,
#   'hotttness_song': 0.3775316449767025,
#   'hotttnesss_artist': 0.45278947675222264,
#   'key': 4,
#   'key_confidence': 0.28299999999999997,
#   'latitude': 27.940169999999998,
#   'location': b'Brandon',
#   'longitude': -82.325469999999996,
#   'loudness': -15.335000000000001,
#   'mbid': b'84f3a2c3-95b4-4d4f-82d9-0e4baf4886ab',
#   'mode': 0,
#   'mode_confidence': 0.36299999999999999,
#   'playmeid': -1,
#   'release': b'The Emperor Falls',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 343187,
#   'seven_trackid': 5158927,
#   'song_id': b'SOLLHMX12AB01846DC',
#   'start_fade': 480.363,
#   'tempo': 138.00700000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.89300000000000002,
#   'title': b'The Emperor Falls',
#   'year': 0},
#  {'artist': b'The Shangri-Las',
#   'artist_id': b'ARAJPHH1187FB5566A',
#   'danceability': 0.0,
#   'duration': 164.80608000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.64080710196367285,
#   'hotttness_song': 0.4432913119053975,
#   'hotttnesss_artist': 0.41821651819493683,
#   'key': 10,
#   'key_confidence': 0.254,
#   'latitude': 40.703800000000001,
#   'location': b'Queens, NY',
#   'longitude': -73.831680000000006,
#   'loudness': -10.922000000000001,
#   'mbid': b'91d01e5f-252d-469d-a16a-12c613e48e5d',
#   'mode': 1,
#   'mode_confidence': 0.042000000000000003,
#   'playmeid': 2995,
#   'release': b'Best of The Shangri-Las',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14045,
#   'seven_trackid': 7133415,
#   'song_id': b'SOYTPEP12AB0180E7B',
#   'start_fade': 156.17699999999999,
#   'tempo': 130.09999999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Twist and Shout',
#   'year': 1964},
#  {'artist': b'Billie Jo Spears',
#   'artist_id': b'AR0RCMP1187FB3F427',
#   'danceability': 0.0,
#   'duration': 133.32853,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.52371463697023279,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.38461108396163651,
#   'key': 4,
#   'key_confidence': 0.38400000000000001,
#   'latitude': 30.08615,
#   'location': b'Beaumont, TX',
#   'longitude': -94.101579999999998,
#   'loudness': -9.9830000000000005,
#   'mbid': b'615d51ca-3d06-43dc-b956-4d76099f4b5e',
#   'mode': 1,
#   'mode_confidence': 0.40200000000000002,
#   'playmeid': 56462,
#   'release': b'20 Of Her Best',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16838,
#   'seven_trackid': 7357260,
#   'song_id': b'SOGXHEG12AB018653E',
#   'start_fade': 130.00899999999999,
#   'tempo': 160.839,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'It Makes No Difference Now',
#   'year': 1992},
#  {'artist': b"Mike Jones (Featuring CJ_ Mello & Lil' Bran)",
#   'artist_id': b'AREBBGV1187FB523D2',
#   'danceability': 0.0,
#   'duration': 173.66158999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.79360508037124167,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42631795640769016,
#   'key': 7,
#   'key_confidence': 0.29899999999999999,
#   'latitude': nan,
#   'location': b'Houston, TX',
#   'longitude': nan,
#   'loudness': -7.7619999999999996,
#   'mbid': b'7685015d-bd3b-4888-9020-3288c421cc9f',
#   'mode': 1,
#   'mode_confidence': 0.46400000000000002,
#   'playmeid': 2567,
#   'release': b'Who Is Mike Jones?',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9222,
#   'seven_trackid': 133966,
#   'song_id': b'SOOLYAZ12A6701F4A6',
#   'start_fade': 164.90799999999999,
#   'tempo': 41.993000000000002,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Laws Patrolling (Album Version)',
#   'year': 0},
#  {'artist': b'Sierra Maestra',
#   'artist_id': b'ARGUVEV1187B98BA17',
#   'danceability': 0.0,
#   'duration': 313.12934000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.50154477710393708,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.39273367554668775,
#   'key': 9,
#   'key_confidence': 0.72399999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.5120000000000005,
#   'mbid': b'017f5df4-c30c-4799-95f7-997bd5b88df7',
#   'mode': 1,
#   'mode_confidence': 0.36399999999999999,
#   'playmeid': 185183,
#   'release': b'Tibiri Tabara',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 107468,
#   'seven_trackid': 3003122,
#   'song_id': b'SOGOSOV12AF72A285E',
#   'start_fade': 307.68799999999999,
#   'tempo': 189.64599999999999,
#   'time_signature': 3,
#   'time_signature_confidence': 0.67400000000000004,
#   'title': b'\xc2\xbfD\xc3\xb3nde va Chichi?',
#   'year': 1997},
#  {'artist': b'Butthole Surfers',
#   'artist_id': b'ARPQ4Z01187FB3A736',
#   'danceability': 0.0,
#   'duration': 450.84688999999997,
#   'end_of_fade': 0.46700000000000003,
#   'energy': 0.0,
#   'familiarity': 0.8093237930019529,
#   'hotttness_song': 0.59394307590194695,
#   'hotttnesss_artist': 0.48801984168567314,
#   'key': 4,
#   'key_confidence': 0.72599999999999998,
#   'latitude': 29.424489999999999,
#   'location': b'San Antonio, TX',
#   'longitude': -98.494619999999998,
#   'loudness': -9.0630000000000006,
#   'mbid': b'2339bc21-aa92-4850-86f0-4bb9433910c8',
#   'mode': 0,
#   'mode_confidence': 0.36699999999999999,
#   'playmeid': 110955,
#   'release': b'Piouhgd + Widowermaker!',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16860,
#   'seven_trackid': 2788206,
#   'song_id': b'SOJXVAH12A8C139700',
#   'start_fade': 426.10399999999998,
#   'tempo': 130.58600000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.41999999999999998,
#   'title': b'Barking Dogs (From "Piouhgd")',
#   'year': 0},
#  {'artist': b'Despina Vandi',
#   'artist_id': b'ARNQAVF11F4C844C04',
#   'danceability': 0.0,
#   'duration': 303.09832,
#   'end_of_fade': 0.067000000000000004,
#   'energy': 0.0,
#   'familiarity': 0.63255954228465106,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.41168895978577885,
#   'key': 8,
#   'key_confidence': 0.53200000000000003,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -8.8789999999999996,
#   'mbid': b'',
#   'mode': 0,
#   'mode_confidence': 0.51600000000000001,
#   'playmeid': 447,
#   'release': b'Profities',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 45784,
#   'seven_trackid': 1658618,
#   'song_id': b'SOVXMTN12A8C135A18',
#   'start_fade': 294.81799999999998,
#   'tempo': 128.292,
#   'time_signature': 4,
#   'time_signature_confidence': 0.82999999999999996,
#   'title': b'OUTE ENA EFHARISTO',
#   'year': 0},
#  {'artist': b'Javier Navarrete',
#   'artist_id': b'ARXUT4W1187FB48BEB',
#   'danceability': 0.0,
#   'duration': 128.83546000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.59754121797238058,
#   'hotttness_song': 0.39439485610058261,
#   'hotttnesss_artist': 0.38265197113973687,
#   'key': 3,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -17.699000000000002,
#   'mbid': b'e927aaaa-323e-4f90-952d-b420212191b2',
#   'mode': 1,
#   'mode_confidence': 0.251,
#   'playmeid': -1,
#   'release': b'Cracks',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 34461,
#   'seven_trackid': 7143933,
#   'song_id': b'SORSECL12AB0182267',
#   'start_fade': 121.423,
#   'tempo': 90.932000000000002,
#   'time_signature': 3,
#   'time_signature_confidence': 1.0,
#   'title': b'Midnight Swim',
#   'year': 0},
#  {'artist': b'Jacob Young',
#   'artist_id': b'ARDD1RC1187B9B52B4',
#   'danceability': 0.0,
#   'duration': 456.30649,
#   'end_of_fade': 0.24099999999999999,
#   'energy': 0.0,
#   'familiarity': 0.49544592177023467,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.29486126188738199,
#   'key': 1,
#   'key_confidence': 0.61099999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -19.478000000000002,
#   'mbid': b'5665cefe-8f12-4328-b66b-2f62644be484',
#   'mode': 1,
#   'mode_confidence': 0.54600000000000004,
#   'playmeid': -1,
#   'release': b'Pieces Of Time',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 125706,
#   'seven_trackid': 8093189,
#   'song_id': b'SOOGFBZ12AC3DF7FF2',
#   'start_fade': 451.315,
#   'tempo': 89.667000000000002,
#   'time_signature': 4,
#   'time_signature_confidence': 0.747,
#   'title': b'In A Subtle Way',
#   'year': 0},
#  {'artist': b"Scarlet's Remains",
#   'artist_id': b'ARLGWFM1187FB4AC9F',
#   'danceability': 0.0,
#   'duration': 198.73913999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.52786507615868183,
#   'hotttness_song': 0.45099231163625503,
#   'hotttnesss_artist': 0.39312193357100678,
#   'key': 7,
#   'key_confidence': 0.67300000000000004,
#   'latitude': 34.053489999999996,
#   'location': b'California - LA',
#   'longitude': -118.24532000000001,
#   'loudness': -7.4690000000000003,
#   'mbid': b'575122b0-bdba-442d-891c-8a8b2999aa98',
#   'mode': 1,
#   'mode_confidence': 0.57899999999999996,
#   'playmeid': -1,
#   'release': b'The Palest Grey',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 527722,
#   'seven_trackid': 7872290,
#   'song_id': b'SOMSBGZ12AB018C4CB',
#   'start_fade': 193.01599999999999,
#   'tempo': 115.06100000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.73099999999999998,
#   'title': b'Spin',
#   'year': 2007},
#  {'artist': b'The Suicide Machines',
#   'artist_id': b'ARWYVP51187B98C516',
#   'danceability': 0.0,
#   'duration': 95.686080000000004,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.66867453286131573,
#   'hotttness_song': 0.52878248094258773,
#   'hotttnesss_artist': 0.4675384440100101,
#   'key': 2,
#   'key_confidence': 0.42099999999999999,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -2.0219999999999998,
#   'mbid': b'c6d2cbdf-30e7-4233-a1b4-e892f116ada1',
#   'mode': 1,
#   'mode_confidence': 0.58899999999999997,
#   'playmeid': -1,
#   'release': b'A Match & Some Gasoline',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 240277,
#   'seven_trackid': 7830058,
#   'song_id': b'SONYRZV12AB018AF70',
#   'start_fade': 87.805999999999997,
#   'tempo': 115.887,
#   'time_signature': 4,
#   'time_signature_confidence': 0.74399999999999999,
#   'title': b'Burning In The Aftermath',
#   'year': 2003},
#  {'artist': b'The Rolling Stones',
#   'artist_id': b'ARFCUN31187B9AD578',
#   'danceability': 0.0,
#   'duration': 271.49016,
#   'end_of_fade': 0.17100000000000001,
#   'energy': 0.0,
#   'familiarity': 0.8148296561331122,
#   'hotttness_song': 0.8344926198909054,
#   'hotttnesss_artist': 0.73576569295064143,
#   'key': 9,
#   'key_confidence': 0.30099999999999999,
#   'latitude': 51.506320000000002,
#   'location': b'London, England',
#   'longitude': -0.12714,
#   'loudness': -10.358000000000001,
#   'mbid': b'b071f9fa-14b0-4217-8e97-eb41da73f598',
#   'mode': 0,
#   'mode_confidence': 0.39200000000000002,
#   'playmeid': 10490,
#   'release': b"Jump Back - The Best Of The Rolling Stones_ '71-'93",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 522,
#   'seven_trackid': 453879,
#   'song_id': b'SONQBUB12A6D4F8ED0',
#   'start_fade': 263.78399999999999,
#   'tempo': 139.333,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Angie (1993 Digital Remaster)',
#   'year': 0},
#  {'artist': b'Roberto Torres',
#   'artist_id': b'AR6YDKV1187B989230',
#   'danceability': 0.0,
#   'duration': 226.66404,
#   'end_of_fade': 0.311,
#   'energy': 0.0,
#   'familiarity': 0.48235604259091081,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.35007857898947331,
#   'key': 0,
#   'key_confidence': 0.86299999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -12.715999999999999,
#   'mbid': b'a3bbee3c-ef45-43e7-bf4f-ba0f871ea716',
#   'mode': 1,
#   'mode_confidence': 0.67100000000000004,
#   'playmeid': -1,
#   'release': b'Lo Mejor con La Orq. Broadway',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 176139,
#   'seven_trackid': 8653966,
#   'song_id': b'SOHGKJW12AC468A8BD',
#   'start_fade': 219.50999999999999,
#   'tempo': 117.271,
#   'time_signature': 4,
#   'time_signature_confidence': 0.45300000000000001,
#   'title': b'Sabor Guajiro',
#   'year': 0},
#  {'artist': b'Loudon Wainwright III',
#   'artist_id': b'ARV1JVD1187B9AD195',
#   'danceability': 0.0,
#   'duration': 190.48444000000001,
#   'end_of_fade': 0.25800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.6610801676039384,
#   'hotttness_song': 0.51011931403303468,
#   'hotttnesss_artist': 0.44276584202895042,
#   'key': 3,
#   'key_confidence': 0.54400000000000004,
#   'latitude': 35.914630000000002,
#   'location': b'Chapel Hill, NC',
#   'longitude': -79.056610000000006,
#   'loudness': -15.663,
#   'mbid': b'3ddc1fe4-0abb-4af0-9392-e36720386842',
#   'mode': 1,
#   'mode_confidence': 0.59599999999999997,
#   'playmeid': 14418,
#   'release': b'Grown Man',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16308,
#   'seven_trackid': 315300,
#   'song_id': b'SOINBCU12A6D4F94C0',
#   'start_fade': 177.029,
#   'tempo': 102.428,
#   'time_signature': 4,
#   'time_signature_confidence': 0.496,
#   'title': b'Human Cannonball',
#   'year': 1995},
#  {'artist': b'R.L. Burnside',
#   'artist_id': b'AR7TTS41187B9B42D3',
#   'danceability': 0.0,
#   'duration': 277.78566999999998,
#   'end_of_fade': 0.23999999999999999,
#   'energy': 0.0,
#   'familiarity': 0.70118087360755066,
#   'hotttness_song': 0.48213758506501503,
#   'hotttnesss_artist': 0.46662888890168458,
#   'key': 2,
#   'key_confidence': 0.0,
#   'latitude': 34.36401,
#   'location': b'Oxford, MS',
#   'longitude': -89.518770000000004,
#   'loudness': -6.944,
#   'mbid': b'355eed00-6c40-4d33-940a-600b2597407a',
#   'mode': 1,
#   'mode_confidence': 0.0,
#   'playmeid': 26588,
#   'release': b'A Bothered Mind',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 6186,
#   'seven_trackid': 6169318,
#   'song_id': b'SOTWVQT12A58A79650',
#   'start_fade': 267.45299999999997,
#   'tempo': 89.983999999999995,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Glory Be',
#   'year': 2004},
#  {'artist': b'Stevie Ray Vaughan',
#   'artist_id': b'ART3O5Z1187B9AB043',
#   'danceability': 0.0,
#   'duration': 248.78975,
#   'end_of_fade': 0.183,
#   'energy': 0.0,
#   'familiarity': 0.7337989404362274,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.54425750572452603,
#   'key': 1,
#   'key_confidence': 0.754,
#   'latitude': 32.778149999999997,
#   'location': b'Dallas, TX',
#   'longitude': -96.795400000000001,
#   'loudness': -7.8049999999999997,
#   'mbid': b'f5426431-f490-4678-ad44-a75c71097bb4',
#   'mode': 1,
#   'mode_confidence': 0.59699999999999998,
#   'playmeid': 9729,
#   'release': b'Greatest Hits',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 48814,
#   'seven_trackid': 4659073,
#   'song_id': b'SOTSEJY12AB0180F56',
#   'start_fade': 246.19,
#   'tempo': 116.721,
#   'time_signature': 4,
#   'time_signature_confidence': 0.52200000000000002,
#   'title': b'Crossfire',
#   'year': 1992},
#  {'artist': b'John Hammond',
#   'artist_id': b'AR5U94U1187FB5CDCF',
#   'danceability': 0.0,
#   'duration': 195.31710000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.59069291794716228,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.45281783769711387,
#   'key': 7,
#   'key_confidence': 0.97999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -10.699999999999999,
#   'mbid': b'd83e599c-2d5a-44ec-b727-587e1455b1b5',
#   'mode': 1,
#   'mode_confidence': 0.753,
#   'playmeid': 7350,
#   'release': b'Bluesman',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 39546,
#   'seven_trackid': 6378564,
#   'song_id': b'SOTSETT12AB01863B8',
#   'start_fade': 187.61699999999999,
#   'tempo': 123.142,
#   'time_signature': 4,
#   'time_signature_confidence': 0.67800000000000005,
#   'title': b"I Can't Be Satisfied",
#   'year': 2002},
#  {'artist': b'Casiotone For The Painfully Alone',
#   'artist_id': b'ARRJNTE1187FB44E12',
#   'danceability': 0.0,
#   'duration': 175.72525999999999,
#   'end_of_fade': 0.73399999999999999,
#   'energy': 0.0,
#   'familiarity': 0.66532216190601845,
#   'hotttness_song': 0.78589228838835379,
#   'hotttnesss_artist': 0.39421719890100421,
#   'key': 0,
#   'key_confidence': 0.52200000000000002,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -10.93,
#   'mbid': b'73d882c7-1146-4012-a61b-a3b2c11fce2f',
#   'mode': 1,
#   'mode_confidence': 0.47399999999999998,
#   'playmeid': -1,
#   'release': b'Etiquette',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 48409,
#   'seven_trackid': 2573759,
#   'song_id': b'SOTUNMH12A6D4FA3E6',
#   'start_fade': 168.69900000000001,
#   'tempo': 141.91900000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.44500000000000001,
#   'title': b'Nashville Parthenon',
#   'year': 2006},
#  {'artist': b'Ec8or',
#   'artist_id': b'AR6IRG41187B9A4D98',
#   'danceability': 0.0,
#   'duration': 217.23383000000001,
#   'end_of_fade': 1.042,
#   'energy': 0.0,
#   'familiarity': 0.50407566993031627,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.33457736011909872,
#   'key': 10,
#   'key_confidence': 0.0050000000000000001,
#   'latitude': 52.516069999999999,
#   'location': b'Berlin, Germany',
#   'longitude': 13.37698,
#   'loudness': -9.4930000000000003,
#   'mbid': b'168e3ccd-91f5-480c-970a-b35171c71164',
#   'mode': 0,
#   'mode_confidence': 0.30499999999999999,
#   'playmeid': -1,
#   'release': b'Ec8or',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 7171,
#   'seven_trackid': 5591305,
#   'song_id': b'SOEPPKB12AB018418B',
#   'start_fade': 213.49600000000001,
#   'tempo': 95.596000000000004,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Cocain Ducks',
#   'year': 1995},
#  {'artist': b'The New York Dolls',
#   'artist_id': b'ARS1OWB1187B99EEAD',
#   'danceability': 0.0,
#   'duration': 344.05831999999998,
#   'end_of_fade': 0.068000000000000005,
#   'energy': 0.0,
#   'familiarity': 0.71767052472855197,
#   'hotttness_song': 0.5616924111789523,
#   'hotttnesss_artist': 0.47930845933822741,
#   'key': 11,
#   'key_confidence': 0.42499999999999999,
#   'latitude': nan,
#   'location': b'New York, NY',
#   'longitude': nan,
#   'loudness': -9.2530000000000001,
#   'mbid': b'1b96b9c9-0832-40cb-9f8d-7274de3733fc',
#   'mode': 1,
#   'mode_confidence': 0.48599999999999999,
#   'playmeid': 5379,
#   'release': b'Too Much Too Soon',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 24313,
#   'seven_trackid': 770031,
#   'song_id': b'SOGKIWV12A6D4F86C4',
#   'start_fade': 335.029,
#   'tempo': 154.953,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Human Being',
#   'year': 1974},
#  {'artist': b'Eliane Elias',
#   'artist_id': b'ARGMXQW1187FB54C34',
#   'danceability': 0.0,
#   'duration': 251.42812000000001,
#   'end_of_fade': 0.070999999999999994,
#   'energy': 0.0,
#   'familiarity': 0.66972618756614455,
#   'hotttness_song': 0.43483809026085618,
#   'hotttnesss_artist': 0.42791424698295477,
#   'key': 7,
#   'key_confidence': 0.39100000000000001,
#   'latitude': -23.56287,
#   'location': b'Sao Paulo, Brazil',
#   'longitude': -46.65466,
#   'loudness': -12.009,
#   'mbid': b'9974cbc1-6a00-4a97-8a36-e4a25bfe0293',
#   'mode': 1,
#   'mode_confidence': 0.31900000000000001,
#   'playmeid': 14229,
#   'release': b'Bossa Nova Stories',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 2800,
#   'seven_trackid': 3635000,
#   'song_id': b'SOPHYIS12AAF3B35A3',
#   'start_fade': 237.59800000000001,
#   'tempo': 86.090999999999994,
#   'time_signature': 5,
#   'time_signature_confidence': 0.55100000000000005,
#   'title': b'The More I See You',
#   'year': 2009},
#  {'artist': b'Lost Boyz',
#   'artist_id': b'AROEL1B1187B988B90',
# ...
#   'mode_confidence': 0.30099999999999999,
#   'playmeid': 24471,
#   'release': b'Never Seen The Light Of Day -Deluxe Version',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9878,
#   'seven_trackid': 3015706,
#   'song_id': b'SOYXFLF12A6D4FBF4E',
#   'start_fade': 133.863,
#   'tempo': 152.041,
#   'time_signature': 4,
#   'time_signature_confidence': 0.36199999999999999,
#   'title': b'Misty Mountains',
#   'year': 2007},
#  {'artist': b'Donnie McClurkin',
#   'artist_id': b'ARF3HEO1187B9AF2F4',
#   'danceability': 0.0,
#   'duration': 198.58240000000001,
#   'end_of_fade': 0.32800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.6060110032472622,
#   'hotttness_song': 0.45744716708510053,
#   'hotttnesss_artist': 0.4872029945562743,
#   'key': 9,
#   'key_confidence': 0.58799999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.1289999999999996,
#   'mbid': b'1cef08dc-0429-4353-9916-9f6f421d61e9',
#   'mode': 1,
#   'mode_confidence': 0.68700000000000006,
#   'playmeid': 7072,
#   'release': b'Donnie McClurkin... Again',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 5198,
#   'seven_trackid': 5846335,
#   'song_id': b'SOTJLKO12A8AE4888B',
#   'start_fade': 191.803,
#   'tempo': 143.98599999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.55600000000000005,
#   'title': b'All I Ever Really Wanted',
#   'year': 0},
#  {'artist': b'NewFound Road',
#   'artist_id': b'ARXBXVM11E9057944C',
#   'danceability': 0.0,
#   'duration': 176.56118000000001,
#   'end_of_fade': 0.107,
#   'energy': 0.0,
#   'familiarity': 0.51850127316668726,
#   'hotttness_song': 0.25383473613223129,
#   'hotttnesss_artist': 0.38370057917998429,
#   'key': 7,
#   'key_confidence': 1.0,
#   'latitude': 40.190330000000003,
#   'location': b'Ohio',
#   'longitude': -82.669470000000004,
#   'loudness': -5.8639999999999999,
#   'mbid': b'f51617fe-32fd-4562-b3d2-9ad12cd97d92',
#   'mode': 1,
#   'mode_confidence': 0.84599999999999997,
#   'playmeid': -1,
#   'release': b'Same Old Place',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 301089,
#   'seven_trackid': 6933888,
#   'song_id': b'SOHSPMJ12AB0181C96',
#   'start_fade': 167.172,
#   'tempo': 223.34,
#   'time_signature': 4,
#   'time_signature_confidence': 0.47999999999999998,
#   'title': b'Brand New Broken Heart',
#   'year': 2009},
#  {'artist': b'Vilma Palma e Vampiros',
#   'artist_id': b'ARS26BQ1187B99466D',
#   'danceability': 0.0,
#   'duration': 210.05016000000001,
#   'end_of_fade': 0.55400000000000005,
#   'energy': 0.0,
#   'familiarity': 0.58811764966422764,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.37810696510421971,
#   'key': 7,
#   'key_confidence': 0.20300000000000001,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.1070000000000002,
#   'mbid': b'a03c336b-5295-4ad8-baa9-0309b47603c4',
#   'mode': 1,
#   'mode_confidence': 0.45400000000000001,
#   'playmeid': 113977,
#   'release': b'Lo Mejor De Vilma Palma',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 78095,
#   'seven_trackid': 1014822,
#   'song_id': b'SOEFZVQ12A8C138735',
#   'start_fade': 194.833,
#   'tempo': 127.803,
#   'time_signature': 4,
#   'time_signature_confidence': 0.58999999999999997,
#   'title': b'Te quiero tanto',
#   'year': 1993},
#  {'artist': b'Ray Conniff',
#   'artist_id': b'ARXZIHJ1187B9A4ED9',
#   'danceability': 0.0,
#   'duration': 191.63382999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.55576499960030001,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.37651423121487881,
#   'key': 0,
#   'key_confidence': 0.14299999999999999,
#   'latitude': 41.945079999999997,
#   'location': b'Attleboro, MA',
#   'longitude': -71.281090000000006,
#   'loudness': -14.286,
#   'mbid': b'b84dfb67-c437-4ccc-b512-1073fd4612eb',
#   'mode': 1,
#   'mode_confidence': 0.39800000000000002,
#   'playmeid': 8531,
#   'release': b'The Hollywood Collection',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 54504,
#   'seven_trackid': 7855564,
#   'song_id': b'SOIDOHE12A8C135371',
#   'start_fade': 185.69,
#   'tempo': 65.852000000000004,
#   'time_signature': 4,
#   'time_signature_confidence': 0.74199999999999999,
#   'title': b'Yesterdays',
#   'year': 0},
#  {'artist': b'Nelson Ned',
#   'artist_id': b'AR6C8EJ1187FB3F473',
#   'danceability': 0.0,
#   'duration': 177.63220000000001,
#   'end_of_fade': 0.32800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.49866364857789747,
#   'hotttness_song': 0.24731709912816252,
#   'hotttnesss_artist': 0.32188268994567615,
#   'key': 9,
#   'key_confidence': 0.39400000000000002,
#   'latitude': nan,
#   'location': b' Ub\xc3\xa1, Minas Gerais',
#   'longitude': nan,
#   'loudness': -12.026,
#   'mbid': b'5c70dd66-e717-4ce3-8940-9a530f492383',
#   'mode': 1,
#   'mode_confidence': 0.51400000000000001,
#   'playmeid': 66900,
#   'release': b'Selecao De Ouro Vol.2',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 17871,
#   'seven_trackid': 365121,
#   'song_id': b'SORTRUL12A6D4FA12A',
#   'start_fade': 168.62899999999999,
#   'tempo': 85.700000000000003,
#   'time_signature': 3,
#   'time_signature_confidence': 0.20699999999999999,
#   'title': b'Mi Sangre Latino',
#   'year': 0},
#  {'artist': b'Madilu System',
#   'artist_id': b'AR199MY1187B9B731E',
#   'danceability': 0.0,
#   'duration': 451.44770999999997,
#   'end_of_fade': 0.23499999999999999,
#   'energy': 0.0,
#   'familiarity': 0.42120914657330533,
#   'hotttness_song': 0.349166902124596,
#   'hotttnesss_artist': 0.29460789278647759,
#   'key': 9,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -3.871,
#   'mbid': b'83f58e18-23d1-40df-818c-5d5d8c536df7',
#   'mode': 1,
#   'mode_confidence': 0.108,
#   'playmeid': -1,
#   'release': b'La Bonne Humeur',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 189121,
#   'seven_trackid': 2809287,
#   'song_id': b'SOMKRRH12A8C13C411',
#   'start_fade': 440.66800000000001,
#   'tempo': 130.126,
#   'time_signature': 5,
#   'time_signature_confidence': 0.77700000000000002,
#   'title': b'Vincent',
#   'year': 0},
#  {'artist': b'Set Your Goals',
#   'artist_id': b'ARKCYJV1187FB392E9',
#   'danceability': 0.0,
#   'duration': 204.40771000000001,
#   'end_of_fade': 2.1480000000000001,
#   'energy': 0.0,
#   'familiarity': 0.82391008735858451,
#   'hotttness_song': 0.71839133028994295,
#   'hotttnesss_artist': 0.54974965158743905,
#   'key': 3,
#   'key_confidence': 0.124,
#   'latitude': nan,
#   'location': b'San Francisco, CA',
#   'longitude': nan,
#   'loudness': -2.1920000000000002,
#   'mbid': b'03d8f83e-a647-4bde-968a-189c0f147783',
#   'mode': 1,
#   'mode_confidence': 0.29899999999999999,
#   'playmeid': 33269,
#   'release': b'This Will Be The Death Of Us',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 66284,
#   'seven_trackid': 5819356,
#   'song_id': b'SOSVWIE12A8C143BD4',
#   'start_fade': 192.78899999999999,
#   'tempo': 194.53200000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.17299999999999999,
#   'title': b'the fallen...',
#   'year': 2009},
#  {'artist': b'The High Strung',
#   'artist_id': b'ARTE6AQ1187B9B2826',
#   'danceability': 0.0,
#   'duration': 153.73016000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.5999446698556915,
#   'hotttness_song': 0.37952332442218817,
#   'hotttnesss_artist': 0.3968002189789247,
#   'key': 9,
#   'key_confidence': 0.623,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -2.6789999999999998,
#   'mbid': b'2b418029-92e6-4aa6-8099-f796fffb3023',
#   'mode': 1,
#   'mode_confidence': 0.63100000000000001,
#   'playmeid': 141898,
#   'release': b'Ode to the Inverse of the Dude',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 124455,
#   'seven_trackid': 4694767,
#   'song_id': b'SOBXEJI12A58A79725',
#   'start_fade': 140.72999999999999,
#   'tempo': 95.109999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.54200000000000004,
#   'title': b'The Lifestyle That Got Away',
#   'year': 2009},
#  {'artist': b'Lost Boyz',
#   'artist_id': b'AROEL1B1187B988B90',
#   'danceability': 0.0,
#   'duration': 243.53914,
#   'end_of_fade': 0.25900000000000001,
#   'energy': 0.0,
#   'familiarity': 0.56974115228189715,
#   'hotttness_song': 0.4081108835105221,
#   'hotttnesss_artist': 0.41224060053560735,
#   'key': 9,
#   'key_confidence': 0.16500000000000001,
#   'latitude': nan,
#   'location': b'South Jamaica, Queens',
#   'longitude': nan,
#   'loudness': -9.7249999999999996,
#   'mbid': b'8b70d4d9-b3d3-4a99-8a95-96ee59f12140',
#   'mode': 1,
#   'mode_confidence': 0.40600000000000003,
#   'playmeid': -1,
#   'release': b'Love_ Peace & Nappiness',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 10275,
#   'seven_trackid': 151794,
#   'song_id': b'SOOTDEC12A6701D0FF',
#   'start_fade': 235.91499999999999,
#   'tempo': 93.174000000000007,
#   'time_signature': 4,
#   'time_signature_confidence': 0.81599999999999995,
#   'title': b'Get Your Hustle On',
#   'year': 1997},
#  {'artist': b'Nic Endo',
#   'artist_id': b'ARQL2SZ1187B99244B',
#   'danceability': 0.0,
#   'duration': 388.0224,
#   'end_of_fade': 2.125,
#   'energy': 0.0,
#   'familiarity': 0.56707373018965423,
#   'hotttness_song': 0.29987748827397781,
#   'hotttnesss_artist': 0.43115980455370512,
#   'key': 3,
#   'key_confidence': 0.33100000000000002,
#   'latitude': 31.168900000000001,
#   'location': b'Texas',
#   'longitude': -100.07715,
#   'loudness': -2.9279999999999999,
#   'mbid': b'433cebcc-b3b3-4516-99ae-63aa991b1401',
#   'mode': 1,
#   'mode_confidence': 0.439,
#   'playmeid': -1,
#   'release': b'White Heat',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 7201,
#   'seven_trackid': 5592299,
#   'song_id': b'SOCAKKR12AB01866C9',
#   'start_fade': 383.94200000000001,
#   'tempo': 88.400000000000006,
#   'time_signature': 5,
#   'time_signature_confidence': 0.54000000000000004,
#   'title': b'Future Prospects',
#   'year': 1998},
#  {'artist': b'Dropkick Murphys',
#   'artist_id': b'ARD2NDU1187B99B615',
#   'danceability': 0.0,
#   'duration': 229.51138,
#   'end_of_fade': 0.13700000000000001,
#   'energy': 0.0,
#   'familiarity': 0.79309437008166128,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.5684918154445614,
#   'key': 9,
#   'key_confidence': 0.90900000000000003,
#   'latitude': nan,
#   'location': b'Boston, MA',
#   'longitude': nan,
#   'loudness': -3.9180000000000001,
#   'mbid': b'e8374874-4178-4869-b92e-fef6bf30dc04',
#   'mode': 1,
#   'mode_confidence': 0.39600000000000002,
#   'playmeid': -1,
#   'release': b'Do Or Die',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 13626,
#   'seven_trackid': 1081263,
#   'song_id': b'SOJWGEI12A8C13CA8F',
#   'start_fade': 223.55600000000001,
#   'tempo': 168.21000000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.621,
#   'title': b'Skinhead on the MBTA (Album Version)',
#   'year': 1997},
#  {'artist': b'Kim Wilson',
#   'artist_id': b'ARSAJKR1187FB4C5DC',
#   'danceability': 0.0,
#   'duration': 286.51056999999997,
#   'end_of_fade': 0.432,
#   'energy': 0.0,
#   'familiarity': 0.45981016275133263,
#   'hotttness_song': 0.26695518627553855,
#   'hotttnesss_artist': 0.32899785889428945,
#   'key': 9,
#   'key_confidence': 0.57699999999999996,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -8.0960000000000001,
#   'mbid': b'd30137de-a6bc-4330-bbbb-743e3551e892',
#   'mode': 1,
#   'mode_confidence': 0.64100000000000001,
#   'playmeid': 93802,
#   'release': b"Lookin' For Trouble!",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 126013,
#   'seven_trackid': 2613430,
#   'song_id': b'SOINZJI12A8C1337A1',
#   'start_fade': 281.05399999999997,
#   'tempo': 119.64400000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Love Attack',
#   'year': 2003},
#  {'artist': b'Daath',
#   'artist_id': b'AR08GQF1187B98E316',
#   'danceability': 0.0,
#   'duration': 248.81586999999999,
#   'end_of_fade': 0.10199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.47396333320767403,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.35070665990043637,
#   'key': 4,
#   'key_confidence': 0.059999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -3.9609999999999999,
#   'mbid': b'9661a587-fdb1-461d-abde-f6280acbde6b',
#   'mode': 0,
#   'mode_confidence': 0.36399999999999999,
#   'playmeid': 7382,
#   'release': b'The Hinderers',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 54581,
#   'seven_trackid': 1432650,
#   'song_id': b'SOBTQGV12A8AE496ED',
#   'start_fade': 248.816,
#   'tempo': 150.16300000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Above Lucium (LP Version)',
#   'year': 2006},
#  {'artist': b'Suicidal Tendencies',
#   'artist_id': b'ARNDB1X1187B990AA0',
#   'danceability': 0.0,
#   'duration': 125.90975,
#   'end_of_fade': 0.30199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.73667741334063197,
#   'hotttness_song': 0.57865818775697131,
#   'hotttnesss_artist': 0.52618255634684785,
#   'key': 11,
#   'key_confidence': 0.76800000000000002,
#   'latitude': 34.053489999999996,
#   'location': b'Venice, CA',
#   'longitude': -118.24532000000001,
#   'loudness': -9.9600000000000009,
#   'mbid': b'e9e2a634-984f-4c10-bf7b-7970179e1ef1',
#   'mode': 0,
#   'mode_confidence': 0.68100000000000005,
#   'playmeid': 12797,
#   'release': b'Join The Army',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16331,
#   'seven_trackid': 1108714,
#   'song_id': b'SOIMSRQ12A6D4F648F',
#   'start_fade': 120.79600000000001,
#   'tempo': 186.15899999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.27800000000000002,
#   'title': b'Human Guinea Pig',
#   'year': 1987},
#  {'artist': b'Bobby Vee',
#   'artist_id': b'ARBUHDB1187FB3E72C',
#   'danceability': 0.0,
#   'duration': 256.28689000000003,
#   'end_of_fade': 0.17699999999999999,
#   'energy': 0.0,
#   'familiarity': 0.62313043687860192,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.39524762318141715,
#   'key': 10,
#   'key_confidence': 0.95899999999999996,
#   'latitude': 46.875909999999998,
#   'location': b'Fargo, ND',
#   'longitude': -96.781760000000006,
#   'loudness': -10.872,
#   'mbid': b'97ebb1b4-1d9c-4303-bb60-074c993e2d53',
#   'mode': 1,
#   'mode_confidence': 0.72499999999999998,
#   'playmeid': 2595,
#   'release': b'Just Today',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16435,
#   'seven_trackid': 5147694,
#   'song_id': b'SOMNRNZ12A8C144C90',
#   'start_fade': 243.93700000000001,
#   'tempo': 132.10900000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.79200000000000004,
#   'title': b'Wink Of An Eye',
#   'year': 0},
#  {'artist': b'Bill & Gloria Gaither',
#   'artist_id': b'ARKC83D1187B9AB367',
#   'danceability': 0.0,
#   'duration': 181.15872999999999,
#   'end_of_fade': 0.12,
#   'energy': 0.0,
#   'familiarity': 0.49392614468639018,
#   'hotttness_song': 0.27077599894632748,
#   'hotttnesss_artist': 0.31962677591740224,
#   'key': 6,
#   'key_confidence': 0.34499999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -13.991,
#   'mbid': b'c55b50e3-5f4e-461d-bf29-79d2c2c364c5',
#   'mode': 0,
#   'mode_confidence': 0.46300000000000002,
#   'playmeid': 62535,
#   'release': b'Israel Homecoming',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 15749,
#   'seven_trackid': 672086,
#   'song_id': b'SOQUGOE12A6D4FA6FF',
#   'start_fade': 173.91200000000001,
#   'tempo': 139.22999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.57799999999999996,
#   'title': b'Awesome God',
#   'year': 0},
#  {'artist': b'Jennifer Brown',
#   'artist_id': b'ARXLOGT1187FB45068',
#   'danceability': 0.0,
#   'duration': 239.07220000000001,
#   'end_of_fade': 0.45900000000000002,
#   'energy': 0.0,
#   'familiarity': 0.49348647312851901,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.38631213060016512,
#   'key': 8,
#   'key_confidence': 0.51200000000000001,
#   'latitude': 34.197670000000002,
#   'location': b'PLAINVIEW, Texas',
#   'longitude': -101.69814,
#   'loudness': -8.2460000000000004,
#   'mbid': b'288af6c6-e5b7-4b2b-8f30-d164a05fa6a3',
#   'mode': 1,
#   'mode_confidence': 0.65500000000000003,
#   'playmeid': -1,
#   'release': b'Vera',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 106363,
#   'seven_trackid': 3412385,
#   'song_id': b'SONYXMF12A8C13EB31',
#   'start_fade': 224.25299999999999,
#   'tempo': 90.915000000000006,
#   'time_signature': 4,
#   'time_signature_confidence': 0.496,
#   'title': b'Naked',
#   'year': 1998},
#  ...]

# %%
import pandas as pd

df = pd.DataFrame(song_data)

# %%
df.head()
# Out:
#                 artist              artist_id  danceability   duration  \
# 0          b'Mastodon'  b'ARMQHX71187B9890D3'           0.0  280.21506
# 1            b'Casual'  b'ARD7TVE1187B99BFB1'           0.0  218.93179
# 2      b'The Box Tops'  b'ARMJAGH1187FB546F3'           0.0  148.03546
# 3  b'Sonora Santanera'  b'ARKRRTF1187B9984DA'           0.0  177.47546
# 4          b'Adam Ant'  b'AR7G5I41187FB4CE6C'           0.0  233.40363
#
#    end_of_fade  energy  familiarity  hotttness_song  hotttnesss_artist  key  \
# 0        0.238     0.0     0.780462        0.597641           0.574275    5
# 1        0.247     0.0     0.581794        0.602120           0.401998    1
# 2        0.148     0.0     0.630630             NaN           0.417500    6
# 3        0.282     0.0     0.487357             NaN           0.343428    8
# 4        0.000     0.0     0.630382             NaN           0.454231    0
#
#    ...   sample_rate_analysis  seven_digital seven_trackid  \
# 0  ...                  22050          29785       2442524
# 1  ...                  22050         165270       3401791
# 2  ...                  22050           1998       3400270
# 3  ...                  22050         290021       5703798
# 4  ...                  22050          19072       3226795
#
#                  song_id  start_fade    tempo  time_signature  \
# 0  b'SOVLGJY12A8C13FBED'     275.528  173.205               5
# 1  b'SOMZWCG12A8C13C480'     218.932   92.198               4
# 2  b'SOCIWDW12A8C13D406'     137.915  121.274               4
# 3  b'SOXVLOJ12AB0189215'     172.304  100.070               1
# 4  b'SONHOTT12A8C13493C'     217.124  119.293               4
#
#    time_signature_confidence                 title  year
# 0                      0.120  b'Deep Sea Creature'  2001
# 1                      0.778   b"I Didn't Mean To"     0
# 2                      0.384          b'Soul Deep'  1969
# 3                      0.000    b'Amor De Cabaret'     0
# 4                      0.000    b'Something Girls'  1982
#
# [5 rows x 30 columns]

# %%
with open('dictionaries/songdata1.pkl', 'rb') as picklefile:
	data_dict = pickle.load(picklefile)
    
data_dict
# Out:
# [{'artist': b'Mastodon',
#   'artist_id': b'ARMQHX71187B9890D3',
#   'danceability': 0.0,
#   'duration': 280.21505999999999,
#   'end_of_fade': 0.23799999999999999,
#   'energy': 0.0,
#   'familiarity': 0.78046174877704066,
#   'hotttness_song': 0.59764079771477685,
#   'hotttnesss_artist': 0.57427473051685607,
#   'key': 5,
#   'key_confidence': 0.55500000000000005,
#   'latitude': nan,
#   'location': b'Atlanta, GA',
#   'longitude': nan,
#   'loudness': -3.306,
#   'mbid': b'bc5e2ad6-0a4a-4d90-b911-e9a7e6861727',
#   'mode': 1,
#   'mode_confidence': 0.5,
#   'playmeid': -1,
#   'release': b'Call of the Mastodon',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 29785,
#   'seven_trackid': 2442524,
#   'song_id': b'SOVLGJY12A8C13FBED',
#   'start_fade': 275.52800000000002,
#   'tempo': 173.20500000000001,
#   'time_signature': 5,
#   'time_signature_confidence': 0.12,
#   'title': b'Deep Sea Creature',
#   'year': 2001},
#  {'artist': b'Casual',
#   'artist_id': b'ARD7TVE1187B99BFB1',
#   'danceability': 0.0,
#   'duration': 218.93179000000001,
#   'end_of_fade': 0.247,
#   'energy': 0.0,
#   'familiarity': 0.58179376584502807,
#   'hotttness_song': 0.60211998990575477,
#   'hotttnesss_artist': 0.40199754336428362,
#   'key': 1,
#   'key_confidence': 0.73599999999999999,
#   'latitude': nan,
#   'location': b'California - LA',
#   'longitude': nan,
#   'loudness': -11.196999999999999,
#   'mbid': b'e77e51a5-4761-45b3-9847-2051f811e366',
#   'mode': 0,
#   'mode_confidence': 0.63600000000000001,
#   'playmeid': 4479,
#   'release': b'Fear Itself',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 165270,
#   'seven_trackid': 3401791,
#   'song_id': b'SOMZWCG12A8C13C480',
#   'start_fade': 218.93199999999999,
#   'tempo': 92.197999999999993,
#   'time_signature': 4,
#   'time_signature_confidence': 0.77800000000000002,
#   'title': b"I Didn't Mean To",
#   'year': 0},
#  {'artist': b'The Box Tops',
#   'artist_id': b'ARMJAGH1187FB546F3',
#   'danceability': 0.0,
#   'duration': 148.03546,
#   'end_of_fade': 0.14799999999999999,
#   'energy': 0.0,
#   'familiarity': 0.63063003758980773,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.41749964497097841,
#   'key': 6,
#   'key_confidence': 0.16900000000000001,
#   'latitude': 35.149679999999996,
#   'location': b'Memphis, TN',
#   'longitude': -90.048919999999995,
#   'loudness': -9.843,
#   'mbid': b'1c78ab62-db33-4433-8d0b-7c8dcf1849c2',
#   'mode': 0,
#   'mode_confidence': 0.42999999999999999,
#   'playmeid': 22066,
#   'release': b'Dimensions',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 1998,
#   'seven_trackid': 3400270,
#   'song_id': b'SOCIWDW12A8C13D406',
#   'start_fade': 137.91499999999999,
#   'tempo': 121.274,
#   'time_signature': 4,
#   'time_signature_confidence': 0.38400000000000001,
#   'title': b'Soul Deep',
#   'year': 1969},
#  {'artist': b'Sonora Santanera',
#   'artist_id': b'ARKRRTF1187B9984DA',
#   'danceability': 0.0,
#   'duration': 177.47546,
#   'end_of_fade': 0.28199999999999997,
#   'energy': 0.0,
#   'familiarity': 0.48735679092814771,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.34342837829688244,
#   'key': 8,
#   'key_confidence': 0.64300000000000002,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.6890000000000001,
#   'mbid': b'7a273984-edd9-4451-9c4d-39b38f05ebcd',
#   'mode': 1,
#   'mode_confidence': 0.56499999999999995,
#   'playmeid': 13951,
#   'release': b'Las Numero 1 De La Sonora Santanera',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 290021,
#   'seven_trackid': 5703798,
#   'song_id': b'SOXVLOJ12AB0189215',
#   'start_fade': 172.304,
#   'tempo': 100.06999999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Amor De Cabaret',
#   'year': 0},
#  {'artist': b'Adam Ant',
#   'artist_id': b'AR7G5I41187FB4CE6C',
#   'danceability': 0.0,
#   'duration': 233.40362999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.63038233414678058,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.45423115657062052,
#   'key': 0,
#   'key_confidence': 0.751,
#   'latitude': nan,
#   'location': b'London, England',
#   'longitude': nan,
#   'loudness': -9.0129999999999999,
#   'mbid': b'e188a520-9cb7-4f73-a3d7-2f70c6538e92',
#   'mode': 1,
#   'mode_confidence': 0.749,
#   'playmeid': 12697,
#   'release': b'Friend Or Foe',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 19072,
#   'seven_trackid': 3226795,
#   'song_id': b'SONHOTT12A8C13493C',
#   'start_fade': 217.124,
#   'tempo': 119.29300000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Something Girls',
#   'year': 1982},
#  {'artist': b'Gob',
#   'artist_id': b'ARXR32B1187FB57099',
#   'danceability': 0.0,
#   'duration': 209.60607999999999,
#   'end_of_fade': 0.066000000000000003,
#   'energy': 0.0,
#   'familiarity': 0.65104566083179471,
#   'hotttness_song': 0.6045007385888197,
#   'hotttnesss_artist': 0.40172368550367865,
#   'key': 2,
#   'key_confidence': 0.091999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -4.5010000000000003,
#   'mbid': b'c6903a2e-063c-4f91-a284-17b8f421be7b',
#   'mode': 1,
#   'mode_confidence': 0.371,
#   'playmeid': 8355,
#   'release': b'Muertos Vivos',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 30973,
#   'seven_trackid': 6795666,
#   'song_id': b'SOFSOCN12A8C143F5D',
#   'start_fade': 198.69900000000001,
#   'tempo': 129.738,
#   'time_signature': 4,
#   'time_signature_confidence': 0.56200000000000006,
#   'title': b'Face the Ashes',
#   'year': 2007},
#  {'artist': b'Jeff And Sheri Easter',
#   'artist_id': b'ARKFYS91187B98E58F',
#   'danceability': 0.0,
#   'duration': 267.70240000000001,
#   'end_of_fade': 2.2639999999999998,
#   'energy': 0.0,
#   'familiarity': 0.53529273551181966,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.38547055055582102,
#   'key': 5,
#   'key_confidence': 0.63500000000000001,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.3230000000000004,
#   'mbid': b'79c403f9-5467-4f23-8426-9ca3fc60a115',
#   'mode': 1,
#   'mode_confidence': 0.55700000000000005,
#   'playmeid': 63801,
#   'release': b'Ordinary Day',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 432935,
#   'seven_trackid': 444964,
#   'song_id': b'SOYMRWW12A6D4FAB14',
#   'start_fade': 254.27000000000001,
#   'tempo': 147.78200000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.45400000000000001,
#   'title': b'The Moon And I (Ordinary Day Album Version)',
#   'year': 0},
#  {'artist': b'Rated R',
#   'artist_id': b'ARD0S291187B9B7BF5',
#   'danceability': 0.0,
#   'duration': 114.78158999999999,
#   'end_of_fade': 0.096000000000000002,
#   'energy': 0.0,
#   'familiarity': 0.55649560191295722,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.26194117738084738,
#   'key': 1,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'Ohio',
#   'longitude': nan,
#   'loudness': -17.302,
#   'mbid': b'56503d6d-094e-4c28-ae3d-04cc748ade5b',
#   'mode': 1,
#   'mode_confidence': 0.0,
#   'playmeid': -1,
#   'release': b'Da Ghetto Psychic',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 17970,
#   'seven_trackid': 276593,
#   'song_id': b'SOMJBYD12A6D4F8557',
#   'start_fade': 114.782,
#   'tempo': 111.78700000000001,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Keepin It Real (Skit)',
#   'year': 0},
#  {'artist': b'Tweeterfriendly Music',
#   'artist_id': b'AR10USD1187B99F3F1',
#   'danceability': 0.0,
#   'duration': 189.57015999999999,
#   'end_of_fade': 0.31900000000000001,
#   'energy': 0.0,
#   'familiarity': 0.80113644699668729,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.60550713569057524,
#   'key': 4,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'Burlington, Ontario, Canada',
#   'longitude': nan,
#   'loudness': -11.641999999999999,
#   'mbid': b'd89de379-665d-425c-b2e9-41b95d1edb36',
#   'mode': 0,
#   'mode_confidence': 0.16,
#   'playmeid': -1,
#   'release': b'Gin & Phonic',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 21128,
#   'seven_trackid': 90004,
#   'song_id': b'SOHKNRJ12A6701D1F8',
#   'start_fade': 181.023,
#   'tempo': 101.43000000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.40799999999999997,
#   'title': b'Drop of Rain',
#   'year': 0},
#  {'artist': b'Planet P Project',
#   'artist_id': b'AR8ZCNI1187B9A069B',
#   'danceability': 0.0,
#   'duration': 269.81832000000003,
#   'end_of_fade': 5.2999999999999998,
#   'energy': 0.0,
#   'familiarity': 0.42666785706940524,
#   'hotttness_song': 0.26586104921065007,
#   'hotttnesss_artist': 0.33227574659906806,
#   'key': 4,
#   'key_confidence': 0.71699999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -13.496,
#   'mbid': b'19d232b9-b4d7-4dc8-b259-bf65efb655b1',
#   'mode': 1,
#   'mode_confidence': 0.65200000000000002,
#   'playmeid': -1,
#   'release': b'Pink World',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 276891,
#   'seven_trackid': 3996579,
#   'song_id': b'SOIAZJW12AB01853F1',
#   'start_fade': 258.99000000000001,
#   'tempo': 86.643000000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.48699999999999999,
#   'title': b'Pink World',
#   'year': 1984},
#  {'artist': b'Clp',
#   'artist_id': b'ARNTLGG11E2835DDB9',
#   'danceability': 0.0,
#   'duration': 266.39627999999999,
#   'end_of_fade': 0.084000000000000005,
#   'energy': 0.0,
#   'familiarity': 0.55051369784821369,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42270564102939107,
#   'key': 7,
#   'key_confidence': 0.052999999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.6970000000000001,
#   'mbid': b'4d96f7d0-2f0e-4e92-ba70-a405f96f8cec',
#   'mode': 0,
#   'mode_confidence': 0.47299999999999998,
#   'playmeid': -1,
#   'release': b'Superinstrumental',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 242273,
#   'seven_trackid': 7684249,
#   'song_id': b'SOUDSGM12AC9618304',
#   'start_fade': 261.74700000000001,
#   'tempo': 114.041,
#   'time_signature': 4,
#   'time_signature_confidence': 0.878,
#   'title': b'Insatiable (Instrumental Version)',
#   'year': 0},
#  {'artist': b'JennyAnyKind',
#   'artist_id': b'ARGSJW91187B9B1D6B',
#   'danceability': 0.0,
#   'duration': 218.77506,
#   'end_of_fade': 2.125,
#   'energy': 0.0,
#   'familiarity': 0.3600311664643514,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.29626895431146333,
#   'key': 5,
#   'key_confidence': 0.35399999999999998,
#   'latitude': 35.219619999999999,
#   'location': b'North Carolina',
#   'longitude': -80.019549999999995,
#   'loudness': -10.021000000000001,
#   'mbid': b'eb722df4-372e-4742-8586-f7ff658012d6',
#   'mode': 0,
#   'mode_confidence': 0.48499999999999999,
#   'playmeid': -1,
#   'release': b'I Need You',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 60488,
#   'seven_trackid': 5967937,
#   'song_id': b'SOQHXMF12AB0182363',
#   'start_fade': 207.012,
#   'tempo': 146.76499999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Young Boy Blues',
#   'year': 0},
#  {'artist': b'Wayne Watson',
#   'artist_id': b'ARC43071187B990240',
#   'danceability': 0.0,
#   'duration': 245.21098000000001,
#   'end_of_fade': 0.35699999999999998,
#   'energy': 0.0,
#   'familiarity': 0.54515929560086318,
#   'hotttness_song': 0.26586104921065007,
#   'hotttnesss_artist': 0.35155586118563925,
#   'key': 7,
#   'key_confidence': 0.070000000000000007,
#   'latitude': nan,
#   'location': b'Wisner, LA',
#   'longitude': nan,
#   'loudness': -7.5449999999999999,
#   'mbid': b'001a1d90-56dc-4992-bd7d-970ecd7105d0',
#   'mode': 1,
#   'mode_confidence': 0.68600000000000005,
#   'playmeid': 17334,
#   'release': b'The Way Home',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 4923,
#   'seven_trackid': 1735859,
#   'song_id': b'SOKEJEJ12A8C13E0D0',
#   'start_fade': 227.47999999999999,
#   'tempo': 117.97499999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.83499999999999996,
#   'title': b'The Urgency (LP Version)',
#   'year': 0},
#  {'artist': b'Andy Andy',
#   'artist_id': b'ARL7K851187B99ACD2',
#   'danceability': 0.0,
#   'duration': 226.35057,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.57750897432529769,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.37948217028046749,
#   'key': 9,
#   'key_confidence': 0.20499999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.6319999999999997,
#   'mbid': b'572d6bb7-58cc-4a96-8e5c-58eae4739190',
#   'mode': 1,
#   'mode_confidence': 0.30499999999999999,
#   'playmeid': 14303,
#   'release': b'Placer & Castigo',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 88523,
#   'seven_trackid': 6381162,
#   'song_id': b'SOMUYGI12AB0188633',
#   'start_fade': 221.553,
#   'tempo': 130.03999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'La Culpa',
#   'year': 0},
#  {'artist': b'Bob Azzam',
#   'artist_id': b'ARHHO3O1187B989413',
#   'danceability': 0.0,
#   'duration': 191.84280999999999,
#   'end_of_fade': 0.38,
#   'energy': 0.0,
#   'familiarity': 0.085512047108578793,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.25193652476242323,
#   'key': 10,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -7.75,
#   'mbid': b'e870caaf-3650-4ed8-9ca1-1ac36419abb0',
#   'mode': 0,
#   'mode_confidence': 0.19800000000000001,
#   'playmeid': -1,
#   'release': b'Arrivederci',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 327171,
#   'seven_trackid': 9014963,
#   'song_id': b'SORAMLE12AB017C8B0',
#   'start_fade': 188.42400000000001,
#   'tempo': 137.334,
#   'time_signature': 1,
#   'time_signature_confidence': 0.31900000000000001,
#   'title': b'Auguri Cha Cha',
#   'year': 0},
#  {'artist': b'Lionel Richie',
#   'artist_id': b'ARIK43K1187B9AE54C',
#   'danceability': 0.0,
#   'duration': 307.38240000000002,
#   'end_of_fade': 0.61199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.77667585568455411,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.55307199146197528,
#   'key': 3,
#   'key_confidence': 0.52400000000000002,
#   'latitude': nan,
#   'location': b'Beverly Hills, CA',
#   'longitude': nan,
#   'loudness': -8.3460000000000001,
#   'mbid': b'3cb25fb2-5547-4b05-adec-1a5e37830d46',
#   'mode': 1,
#   'mode_confidence': 0.53300000000000003,
#   'playmeid': -1,
#   'release': b'Dancing On The Ceiling',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 237,
#   'seven_trackid': 276438,
#   'song_id': b'SOBONFF12A6D4F84D8',
#   'start_fade': 296.65800000000002,
#   'tempo': 125.197,
#   'time_signature': 3,
#   'time_signature_confidence': 0.21099999999999999,
#   'title': b'Tonight Will Be Alright',
#   'year': 1986},
#  {'artist': b'Blue Rodeo',
#   'artist_id': b'ARD842G1187B997376',
#   'danceability': 0.0,
#   'duration': 491.12770999999998,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.63642364495006976,
#   'hotttness_song': 0.40511572169138649,
#   'hotttnesss_artist': 0.44793548047950221,
#   'key': 7,
#   'key_confidence': 1.0,
#   'latitude': 43.648560000000003,
#   'location': b'Toronto, Ontario, Canada',
#   'longitude': -79.385329999999996,
#   'loudness': -8.5760000000000005,
#   'mbid': b'6b52e1be-f27a-433c-b51a-3f2d63abc2ba',
#   'mode': 1,
#   'mode_confidence': 0.82899999999999996,
#   'playmeid': -1,
#   'release': b'Outskirts',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 3950,
#   'seven_trackid': 1399936,
#   'song_id': b'SOHUOAP12A8AE488E9',
#   'start_fade': 486.03399999999999,
#   'tempo': 119.82599999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.75600000000000001,
#   'title': b'Floating',
#   'year': 1987},
#  {'artist': b'Richard Souther',
#   'artist_id': b'ARIG6O41187B988BDD',
#   'danceability': 0.0,
#   'duration': 228.59710000000001,
#   'end_of_fade': 0.223,
#   'energy': 0.0,
#   'familiarity': 0.4199431484349393,
#   'hotttness_song': 0.33470654906922059,
#   'hotttnesss_artist': 0.33080635685585685,
#   'key': 8,
#   'key_confidence': 0.041000000000000002,
#   'latitude': 37.167929999999998,
#   'location': b'United States',
#   'longitude': -95.845020000000005,
#   'loudness': -16.109999999999999,
#   'mbid': b'9f6413ef-4320-4833-87be-3ad1d3bf238f',
#   'mode': 1,
#   'mode_confidence': 0.51600000000000001,
#   'playmeid': 18135,
#   'release': b'Cross Currents',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 24687,
#   'seven_trackid': 1560940,
#   'song_id': b'SOUQQEA12A8C134B1B',
#   'start_fade': 217.42599999999999,
#   'tempo': 127.756,
#   'time_signature': 5,
#   'time_signature_confidence': 0.57899999999999996,
#   'title': b'High Tide',
#   'year': 0},
#  {'artist': b'Faiz Ali Faiz',
#   'artist_id': b'AR1ZHYZ1187FB3C717',
#   'danceability': 0.0,
#   'duration': 599.24852999999996,
#   'end_of_fade': 1.1930000000000001,
#   'energy': 0.0,
#   'familiarity': 0.36328057110998851,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.30667609347902947,
#   'key': 6,
#   'key_confidence': 0.059999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -8.032,
#   'mbid': b'762e2728-f093-4548-8f36-f4580d83e207',
#   'mode': 1,
#   'mode_confidence': 0.34599999999999997,
#   'playmeid': -1,
#   'release': b'Panjtan Ka Ghulam',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 248913,
#   'seven_trackid': 5916675,
#   'song_id': b'SOILPQQ12AB017E82A',
#   'start_fade': 591.99900000000002,
#   'tempo': 99.272999999999996,
#   'time_signature': 4,
#   'time_signature_confidence': 0.158,
#   'title': b'Sohna Nee Sohna Data',
#   'year': 0},
#  {'artist': b'Tesla',
#   'artist_id': b'ARYKCQI1187FB3B18F',
#   'danceability': 0.0,
#   'duration': 290.29831999999999,
#   'end_of_fade': 0.14499999999999999,
#   'energy': 0.0,
#   'familiarity': 0.70719976383793626,
#   'hotttness_song': 0.68413619122949032,
#   'hotttnesss_artist': 0.51346328970215582,
#   'key': 7,
#   'key_confidence': 0.72499999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -5.2709999999999999,
#   'mbid': b'eeacb319-8d4c-48e0-80a0-944e71c375bf',
#   'mode': 1,
#   'mode_confidence': 0.75600000000000001,
#   'playmeid': 7536,
#   'release': b'Gold',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 1396,
#   'seven_trackid': 4143071,
#   'song_id': b'SOXLBJT12A8C140925',
#   'start_fade': 285.60500000000002,
#   'tempo': 150.06200000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.93100000000000005,
#   'title': b'Caught In A Dream',
#   'year': 2004},
#  {'artist': b'lextrical',
#   'artist_id': b'ARNPAGP1241B9C7FD4',
#   'danceability': 0.0,
#   'duration': 165.69424000000001,
#   'end_of_fade': 0.16200000000000001,
#   'energy': 0.0,
#   'familiarity': 0.32031437017067216,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.0,
#   'key': 7,
#   'key_confidence': 0.010999999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.7869999999999999,
#   'mbid': b'',
#   'mode': 1,
#   'mode_confidence': 0.56799999999999995,
#   'playmeid': -1,
#   'release': b'Whatever Happened To Boredom?',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 399889,
#   'seven_trackid': 5991843,
#   'song_id': b'SOZVMJI12AB01808AF',
#   'start_fade': 157.39099999999999,
#   'tempo': 138.33099999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.127,
#   'title': b'Synthetic Dream',
#   'year': 0},
#  {'artist': b'Jimmy Wakely',
#   'artist_id': b'ARQGYP71187FB44566',
#   'danceability': 0.0,
#   'duration': 151.84934000000001,
#   'end_of_fade': 2.827,
#   'energy': 0.0,
#   'familiarity': 0.39413853984589253,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.29153972708877773,
#   'key': 1,
#   'key_confidence': 0.79900000000000004,
#   'latitude': 34.31109,
#   'location': b'Mineola, AR',
#   'longitude': -94.029780000000002,
#   'loudness': -15.221,
#   'mbid': b'0b8f67b3-b1d8-4d7a-8317-9d2e7e1cb277',
#   'mode': 1,
#   'mode_confidence': 0.71599999999999997,
#   'playmeid': 156926,
#   'release': b'1942-1952 Jimmy Wakely',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 34818,
#   'seven_trackid': 6721979,
#   'song_id': b'SOWTBJW12AC468AC6E',
#   'start_fade': 146.19900000000001,
#   'tempo': 86.186000000000007,
#   'time_signature': 3,
#   'time_signature_confidence': 0.92900000000000005,
#   'title': b'Broken-Down Merry-Go-Round',
#   'year': 0},
#  {'artist': b'Alice Stuart',
#   'artist_id': b'ARI3BMM1187FB4255E',
#   'danceability': 0.0,
#   'duration': 220.78648999999999,
#   'end_of_fade': 0.20599999999999999,
#   'energy': 0.0,
#   'familiarity': 0.48981626898204073,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.32855301501801859,
#   'key': 11,
#   'key_confidence': 0.80900000000000005,
#   'latitude': 38.899099999999997,
#   'location': b'Washington',
#   'longitude': -77.028999999999996,
#   'loudness': -8.5139999999999993,
#   'mbid': b'c5bca5a8-1357-4f4c-8544-b36c814ff6d6',
#   'mode': 1,
#   'mode_confidence': 0.52100000000000002,
#   'playmeid': -1,
#   'release': b'All The Good Times',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 185559,
#   'seven_trackid': 3006504,
#   'song_id': b'SOBEBDG12A58A76D60',
#   'start_fade': 207.65600000000001,
#   'tempo': 110.38200000000001,
#   'time_signature': 1,
#   'time_signature_confidence': 0.192,
#   'title': b'Kassie Jones',
#   'year': 0},
#  {'artist': b'Elena',
#   'artist_id': b'AR5KOSW1187FB35FF4',
#   'danceability': 0.0,
#   'duration': 269.58321999999998,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.67742046522622978,
#   'hotttness_song': 0.31356211424793418,
#   'hotttnesss_artist': 0.37825468551016656,
#   'key': 2,
#   'key_confidence': 0.59599999999999997,
#   'latitude': 49.803879999999999,
#   'location': b'Dubai UAE',
#   'longitude': 15.474909999999999,
#   'loudness': -8.0500000000000007,
#   'mbid': b'd3cc4c24-1b5b-4d71-bcc9-1940e0e3e9d3',
#   'mode': 1,
#   'mode_confidence': 0.66600000000000004,
#   'playmeid': 34776,
#   'release': b'Un cafe_ setanta matins',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 69720,
#   'seven_trackid': 4292004,
#   'song_id': b'SOZCTXZ12AB0182364',
#   'start_fade': 256.16800000000001,
#   'tempo': 111.874,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Setanta matins',
#   'year': 0},
#  {'artist': b'The Dillinger Escape Plan',
#   'artist_id': b'ARMAC4T1187FB3FA4C',
#   'danceability': 0.0,
#   'duration': 207.77751000000001,
#   'end_of_fade': 0.060999999999999999,
#   'energy': 0.0,
#   'familiarity': 0.83996276815103699,
#   'hotttness_song': 0.66652784622970229,
#   'hotttnesss_artist': 0.54188897203364694,
#   'key': 7,
#   'key_confidence': 0.38100000000000001,
#   'latitude': 40.826239999999999,
#   'location': b'Morris Plains, NJ',
#   'longitude': -74.479950000000002,
#   'loudness': -4.2640000000000002,
#   'mbid': b'1bc41dff-5397-4c53-bb50-469d2c277197',
#   'mode': 1,
#   'mode_confidence': 0.45300000000000001,
#   'playmeid': 11414,
#   'release': b'Miss Machine',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 82239,
#   'seven_trackid': 2439720,
#   'song_id': b'SOBBUGU12A8C13E95D',
#   'start_fade': 204.696,
#   'tempo': 166.86199999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Setting Fire to Sleeping Giants',
#   'year': 2004},
#  {'artist': b'SUE THOMPSON',
#   'artist_id': b'AR47JEX1187B995D81',
#   'danceability': 0.0,
#   'duration': 124.86485,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.43541581815506936,
#   'hotttness_song': 0.49529362129216348,
#   'hotttnesss_artist': 0.3062422642462862,
#   'key': 10,
#   'key_confidence': 0.69699999999999995,
#   'latitude': 37.837209999999999,
#   'location': b'Nevada, MO',
#   'longitude': -94.358680000000007,
#   'loudness': -12.332000000000001,
#   'mbid': b'7994b392-4b14-4b06-b591-fd8b0ad65338',
#   'mode': 1,
#   'mode_confidence': 0.54100000000000004,
#   'playmeid': -1,
#   'release': b'Sue Thompson - Her Very Best',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 36525,
#   'seven_trackid': 7232396,
#   'song_id': b'SOBLGCN12AB0183212',
#   'start_fade': 115.73999999999999,
#   'tempo': 137.52199999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'James (Hold The Ladder Steady)',
#   'year': 1985},
#  {'artist': b'Five Bolt Main',
#   'artist_id': b'ARGIWFO1187B9B55B7',
#   'danceability': 0.0,
#   'duration': 225.09669,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.60906370003105015,
#   'hotttness_song': 0.37598430150044215,
#   'hotttnesss_artist': 0.3636513650591166,
#   'key': 7,
#   'key_confidence': 0.53000000000000003,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -5.9080000000000004,
#   'mbid': b'34f4bdc2-ed51-44da-af51-7e507d9d4721',
#   'mode': 1,
#   'mode_confidence': 0.51200000000000001,
#   'playmeid': -1,
#   'release': b'Live',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14773,
#   'seven_trackid': 488005,
#   'song_id': b'SOPSWQW12A6D4F8781',
#   'start_fade': 225.09700000000001,
#   'tempo': 164.672,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Made Like This (Live)',
#   'year': 0},
#  {'artist': b'Clp',
#   'artist_id': b'ARNTLGG11E2835DDB9',
#   'danceability': 0.0,
#   'duration': 338.31137999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.55051369784821369,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42270564102939107,
#   'key': 6,
#   'key_confidence': 0.68700000000000006,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.4859999999999998,
#   'mbid': b'4d96f7d0-2f0e-4e92-ba70-a405f96f8cec',
#   'mode': 0,
#   'mode_confidence': 0.48599999999999999,
#   'playmeid': -1,
#   'release': b'Strictly Confidential',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 242273,
#   'seven_trackid': 7448953,
#   'song_id': b'SOZQDIU12A58A7BCF6',
#   'start_fade': 338.31099999999998,
#   'tempo': 125.006,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Superconfidential',
#   'year': 0},
#  {'artist': b'Tim Wilson',
#   'artist_id': b'ARDNS031187B9924F0',
#   'danceability': 0.0,
#   'duration': 186.48770999999999,
#   'end_of_fade': 1.083,
#   'energy': 0.0,
#   'familiarity': 0.45979712883761042,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.34991261167456278,
#   'key': 5,
#   'key_confidence': 0.76200000000000001,
#   'latitude': 32.678280000000001,
#   'location': b'Georgia',
#   'longitude': -83.222949999999997,
#   'loudness': -4.516,
#   'mbid': b'e29641cc-3658-4886-89d7-3a146d2d3d75',
#   'mode': 1,
#   'mode_confidence': 0.53900000000000003,
#   'playmeid': 7570,
#   'release': b'The Real Twang Thang',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14504,
#   'seven_trackid': 1699837,
#   'song_id': b'SONYPOM12A8C13B2D7',
#   'start_fade': 175.46700000000001,
#   'tempo': 90.022000000000006,
#   'time_signature': 1,
#   'time_signature_confidence': 0.97099999999999997,
#   'title': b'I Think My Wife Is Running Around On Me (Taco Hell)',
#   'year': 2005},
#  {'artist': b'Willie Bobo',
#   'artist_id': b'AROUOZZ1187B9ABE51',
#   'danceability': 0.0,
#   'duration': 168.25424000000001,
#   'end_of_fade': 0.20000000000000001,
#   'energy': 0.0,
#   'familiarity': 0.58882710050180576,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.37967112474986731,
#   'key': 8,
#   'key_confidence': 0.81200000000000006,
#   'latitude': 40.79195,
#   'location': b'New York, NY [Spanish Harlem]',
#   'longitude': -73.945120000000003,
#   'loudness': -9.6159999999999997,
#   'mbid': b'dadec058-023e-498a-b1c7-776d03cc88ce',
#   'mode': 1,
#   'mode_confidence': 0.73599999999999999,
#   'playmeid': -1,
#   'release': b"Willie Bobo's Finest Hour",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 15815,
#   'seven_trackid': 618725,
#   'song_id': b'SOBZBAZ12A6D4F8742',
#   'start_fade': 161.88999999999999,
#   'tempo': 127.02500000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.79200000000000004,
#   'title': b'Spanish Grease',
#   'year': 1997},
#  {'artist': b'Faye Adams',
#   'artist_id': b'ARH4Z031187B9A71F2',
#   'danceability': 0.0,
#   'duration': 156.39465000000001,
#   'end_of_fade': 0.56200000000000006,
#   'energy': 0.0,
#   'familiarity': 0.39645525391729608,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.2992303679293693,
#   'key': 8,
#   'key_confidence': 0.56899999999999995,
#   'latitude': 40.731969999999997,
#   'location': b'Newark, NJ',
#   'longitude': -74.174180000000007,
#   'loudness': -18.050999999999998,
#   'mbid': b'8f2974e0-3647-48f6-86f8-603a2c5f31ae',
#   'mode': 1,
#   'mode_confidence': 0.495,
#   'playmeid': 70806,
#   'release': b'Shake A Hand',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 28882,
#   'seven_trackid': 5660441,
#   'song_id': b'SOVYKGO12AB0187199',
#   'start_fade': 150.63399999999999,
#   'tempo': 95.956999999999994,
#   'time_signature': 3,
#   'time_signature_confidence': 0.68899999999999995,
#   'title': b'Crazy Mixed Up World',
#   'year': 1961},
#  {'artist': b'Terry Callier',
#   'artist_id': b'ARB29H41187B98F0EF',
#   'danceability': 0.0,
#   'duration': 342.56934000000001,
#   'end_of_fade': 0.063,
#   'energy': 0.0,
#   'familiarity': 0.70682767130445823,
#   'hotttness_song': 0.41373983586010971,
#   'hotttnesss_artist': 0.4161730646266773,
#   'key': 6,
#   'key_confidence': 0.38100000000000001,
#   'latitude': 41.884149999999998,
#   'location': b'Chicago',
#   'longitude': -87.632409999999993,
#   'loudness': -11.939,
#   'mbid': b'44fd61e1-119c-479e-8301-8ac5c77148bf',
#   'mode': 1,
#   'mode_confidence': 0.53800000000000003,
#   'playmeid': 43725,
#   'release': b'Occasional Rain',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9947,
#   'seven_trackid': 2503960,
#   'song_id': b'SOGNCJP12A58A80271',
#   'start_fade': 333.154,
#   'tempo': 110.18899999999999,
#   'time_signature': 3,
#   'time_signature_confidence': 0.35299999999999998,
#   'title': b'Do You Finally Need A Friend',
#   'year': 1972},
#  {'artist': b'John Wesley',
#   'artist_id': b'AR1Y2PT1187FB5B9CE',
#   'danceability': 0.0,
#   'duration': 484.62322,
#   'end_of_fade': 28.172000000000001,
#   'energy': 0.0,
#   'familiarity': 0.56055798390381462,
#   'hotttness_song': 0.3775316449767025,
#   'hotttnesss_artist': 0.45278947675222264,
#   'key': 4,
#   'key_confidence': 0.28299999999999997,
#   'latitude': 27.940169999999998,
#   'location': b'Brandon',
#   'longitude': -82.325469999999996,
#   'loudness': -15.335000000000001,
#   'mbid': b'84f3a2c3-95b4-4d4f-82d9-0e4baf4886ab',
#   'mode': 0,
#   'mode_confidence': 0.36299999999999999,
#   'playmeid': -1,
#   'release': b'The Emperor Falls',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 343187,
#   'seven_trackid': 5158927,
#   'song_id': b'SOLLHMX12AB01846DC',
#   'start_fade': 480.363,
#   'tempo': 138.00700000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.89300000000000002,
#   'title': b'The Emperor Falls',
#   'year': 0},
#  {'artist': b'The Shangri-Las',
#   'artist_id': b'ARAJPHH1187FB5566A',
#   'danceability': 0.0,
#   'duration': 164.80608000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.64080710196367285,
#   'hotttness_song': 0.4432913119053975,
#   'hotttnesss_artist': 0.41821651819493683,
#   'key': 10,
#   'key_confidence': 0.254,
#   'latitude': 40.703800000000001,
#   'location': b'Queens, NY',
#   'longitude': -73.831680000000006,
#   'loudness': -10.922000000000001,
#   'mbid': b'91d01e5f-252d-469d-a16a-12c613e48e5d',
#   'mode': 1,
#   'mode_confidence': 0.042000000000000003,
#   'playmeid': 2995,
#   'release': b'Best of The Shangri-Las',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 14045,
#   'seven_trackid': 7133415,
#   'song_id': b'SOYTPEP12AB0180E7B',
#   'start_fade': 156.17699999999999,
#   'tempo': 130.09999999999999,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Twist and Shout',
#   'year': 1964},
#  {'artist': b'Billie Jo Spears',
#   'artist_id': b'AR0RCMP1187FB3F427',
#   'danceability': 0.0,
#   'duration': 133.32853,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.52371463697023279,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.38461108396163651,
#   'key': 4,
#   'key_confidence': 0.38400000000000001,
#   'latitude': 30.08615,
#   'location': b'Beaumont, TX',
#   'longitude': -94.101579999999998,
#   'loudness': -9.9830000000000005,
#   'mbid': b'615d51ca-3d06-43dc-b956-4d76099f4b5e',
#   'mode': 1,
#   'mode_confidence': 0.40200000000000002,
#   'playmeid': 56462,
#   'release': b'20 Of Her Best',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16838,
#   'seven_trackid': 7357260,
#   'song_id': b'SOGXHEG12AB018653E',
#   'start_fade': 130.00899999999999,
#   'tempo': 160.839,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'It Makes No Difference Now',
#   'year': 1992},
#  {'artist': b"Mike Jones (Featuring CJ_ Mello & Lil' Bran)",
#   'artist_id': b'AREBBGV1187FB523D2',
#   'danceability': 0.0,
#   'duration': 173.66158999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.79360508037124167,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.42631795640769016,
#   'key': 7,
#   'key_confidence': 0.29899999999999999,
#   'latitude': nan,
#   'location': b'Houston, TX',
#   'longitude': nan,
#   'loudness': -7.7619999999999996,
#   'mbid': b'7685015d-bd3b-4888-9020-3288c421cc9f',
#   'mode': 1,
#   'mode_confidence': 0.46400000000000002,
#   'playmeid': 2567,
#   'release': b'Who Is Mike Jones?',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9222,
#   'seven_trackid': 133966,
#   'song_id': b'SOOLYAZ12A6701F4A6',
#   'start_fade': 164.90799999999999,
#   'tempo': 41.993000000000002,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Laws Patrolling (Album Version)',
#   'year': 0},
#  {'artist': b'Sierra Maestra',
#   'artist_id': b'ARGUVEV1187B98BA17',
#   'danceability': 0.0,
#   'duration': 313.12934000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.50154477710393708,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.39273367554668775,
#   'key': 9,
#   'key_confidence': 0.72399999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -9.5120000000000005,
#   'mbid': b'017f5df4-c30c-4799-95f7-997bd5b88df7',
#   'mode': 1,
#   'mode_confidence': 0.36399999999999999,
#   'playmeid': 185183,
#   'release': b'Tibiri Tabara',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 107468,
#   'seven_trackid': 3003122,
#   'song_id': b'SOGOSOV12AF72A285E',
#   'start_fade': 307.68799999999999,
#   'tempo': 189.64599999999999,
#   'time_signature': 3,
#   'time_signature_confidence': 0.67400000000000004,
#   'title': b'\xc2\xbfD\xc3\xb3nde va Chichi?',
#   'year': 1997},
#  {'artist': b'Butthole Surfers',
#   'artist_id': b'ARPQ4Z01187FB3A736',
#   'danceability': 0.0,
#   'duration': 450.84688999999997,
#   'end_of_fade': 0.46700000000000003,
#   'energy': 0.0,
#   'familiarity': 0.8093237930019529,
#   'hotttness_song': 0.59394307590194695,
#   'hotttnesss_artist': 0.48801984168567314,
#   'key': 4,
#   'key_confidence': 0.72599999999999998,
#   'latitude': 29.424489999999999,
#   'location': b'San Antonio, TX',
#   'longitude': -98.494619999999998,
#   'loudness': -9.0630000000000006,
#   'mbid': b'2339bc21-aa92-4850-86f0-4bb9433910c8',
#   'mode': 0,
#   'mode_confidence': 0.36699999999999999,
#   'playmeid': 110955,
#   'release': b'Piouhgd + Widowermaker!',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16860,
#   'seven_trackid': 2788206,
#   'song_id': b'SOJXVAH12A8C139700',
#   'start_fade': 426.10399999999998,
#   'tempo': 130.58600000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.41999999999999998,
#   'title': b'Barking Dogs (From "Piouhgd")',
#   'year': 0},
#  {'artist': b'Despina Vandi',
#   'artist_id': b'ARNQAVF11F4C844C04',
#   'danceability': 0.0,
#   'duration': 303.09832,
#   'end_of_fade': 0.067000000000000004,
#   'energy': 0.0,
#   'familiarity': 0.63255954228465106,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.41168895978577885,
#   'key': 8,
#   'key_confidence': 0.53200000000000003,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -8.8789999999999996,
#   'mbid': b'',
#   'mode': 0,
#   'mode_confidence': 0.51600000000000001,
#   'playmeid': 447,
#   'release': b'Profities',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 45784,
#   'seven_trackid': 1658618,
#   'song_id': b'SOVXMTN12A8C135A18',
#   'start_fade': 294.81799999999998,
#   'tempo': 128.292,
#   'time_signature': 4,
#   'time_signature_confidence': 0.82999999999999996,
#   'title': b'OUTE ENA EFHARISTO',
#   'year': 0},
#  {'artist': b'Javier Navarrete',
#   'artist_id': b'ARXUT4W1187FB48BEB',
#   'danceability': 0.0,
#   'duration': 128.83546000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.59754121797238058,
#   'hotttness_song': 0.39439485610058261,
#   'hotttnesss_artist': 0.38265197113973687,
#   'key': 3,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -17.699000000000002,
#   'mbid': b'e927aaaa-323e-4f90-952d-b420212191b2',
#   'mode': 1,
#   'mode_confidence': 0.251,
#   'playmeid': -1,
#   'release': b'Cracks',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 34461,
#   'seven_trackid': 7143933,
#   'song_id': b'SORSECL12AB0182267',
#   'start_fade': 121.423,
#   'tempo': 90.932000000000002,
#   'time_signature': 3,
#   'time_signature_confidence': 1.0,
#   'title': b'Midnight Swim',
#   'year': 0},
#  {'artist': b'Jacob Young',
#   'artist_id': b'ARDD1RC1187B9B52B4',
#   'danceability': 0.0,
#   'duration': 456.30649,
#   'end_of_fade': 0.24099999999999999,
#   'energy': 0.0,
#   'familiarity': 0.49544592177023467,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.29486126188738199,
#   'key': 1,
#   'key_confidence': 0.61099999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -19.478000000000002,
#   'mbid': b'5665cefe-8f12-4328-b66b-2f62644be484',
#   'mode': 1,
#   'mode_confidence': 0.54600000000000004,
#   'playmeid': -1,
#   'release': b'Pieces Of Time',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 125706,
#   'seven_trackid': 8093189,
#   'song_id': b'SOOGFBZ12AC3DF7FF2',
#   'start_fade': 451.315,
#   'tempo': 89.667000000000002,
#   'time_signature': 4,
#   'time_signature_confidence': 0.747,
#   'title': b'In A Subtle Way',
#   'year': 0},
#  {'artist': b"Scarlet's Remains",
#   'artist_id': b'ARLGWFM1187FB4AC9F',
#   'danceability': 0.0,
#   'duration': 198.73913999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.52786507615868183,
#   'hotttness_song': 0.45099231163625503,
#   'hotttnesss_artist': 0.39312193357100678,
#   'key': 7,
#   'key_confidence': 0.67300000000000004,
#   'latitude': 34.053489999999996,
#   'location': b'California - LA',
#   'longitude': -118.24532000000001,
#   'loudness': -7.4690000000000003,
#   'mbid': b'575122b0-bdba-442d-891c-8a8b2999aa98',
#   'mode': 1,
#   'mode_confidence': 0.57899999999999996,
#   'playmeid': -1,
#   'release': b'The Palest Grey',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 527722,
#   'seven_trackid': 7872290,
#   'song_id': b'SOMSBGZ12AB018C4CB',
#   'start_fade': 193.01599999999999,
#   'tempo': 115.06100000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.73099999999999998,
#   'title': b'Spin',
#   'year': 2007},
#  {'artist': b'The Suicide Machines',
#   'artist_id': b'ARWYVP51187B98C516',
#   'danceability': 0.0,
#   'duration': 95.686080000000004,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.66867453286131573,
#   'hotttness_song': 0.52878248094258773,
#   'hotttnesss_artist': 0.4675384440100101,
#   'key': 2,
#   'key_confidence': 0.42099999999999999,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -2.0219999999999998,
#   'mbid': b'c6d2cbdf-30e7-4233-a1b4-e892f116ada1',
#   'mode': 1,
#   'mode_confidence': 0.58899999999999997,
#   'playmeid': -1,
#   'release': b'A Match & Some Gasoline',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 240277,
#   'seven_trackid': 7830058,
#   'song_id': b'SONYRZV12AB018AF70',
#   'start_fade': 87.805999999999997,
#   'tempo': 115.887,
#   'time_signature': 4,
#   'time_signature_confidence': 0.74399999999999999,
#   'title': b'Burning In The Aftermath',
#   'year': 2003},
#  {'artist': b'The Rolling Stones',
#   'artist_id': b'ARFCUN31187B9AD578',
#   'danceability': 0.0,
#   'duration': 271.49016,
#   'end_of_fade': 0.17100000000000001,
#   'energy': 0.0,
#   'familiarity': 0.8148296561331122,
#   'hotttness_song': 0.8344926198909054,
#   'hotttnesss_artist': 0.73576569295064143,
#   'key': 9,
#   'key_confidence': 0.30099999999999999,
#   'latitude': 51.506320000000002,
#   'location': b'London, England',
#   'longitude': -0.12714,
#   'loudness': -10.358000000000001,
#   'mbid': b'b071f9fa-14b0-4217-8e97-eb41da73f598',
#   'mode': 0,
#   'mode_confidence': 0.39200000000000002,
#   'playmeid': 10490,
#   'release': b"Jump Back - The Best Of The Rolling Stones_ '71-'93",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 522,
#   'seven_trackid': 453879,
#   'song_id': b'SONQBUB12A6D4F8ED0',
#   'start_fade': 263.78399999999999,
#   'tempo': 139.333,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Angie (1993 Digital Remaster)',
#   'year': 0},
#  {'artist': b'Roberto Torres',
#   'artist_id': b'AR6YDKV1187B989230',
#   'danceability': 0.0,
#   'duration': 226.66404,
#   'end_of_fade': 0.311,
#   'energy': 0.0,
#   'familiarity': 0.48235604259091081,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.35007857898947331,
#   'key': 0,
#   'key_confidence': 0.86299999999999999,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -12.715999999999999,
#   'mbid': b'a3bbee3c-ef45-43e7-bf4f-ba0f871ea716',
#   'mode': 1,
#   'mode_confidence': 0.67100000000000004,
#   'playmeid': -1,
#   'release': b'Lo Mejor con La Orq. Broadway',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 176139,
#   'seven_trackid': 8653966,
#   'song_id': b'SOHGKJW12AC468A8BD',
#   'start_fade': 219.50999999999999,
#   'tempo': 117.271,
#   'time_signature': 4,
#   'time_signature_confidence': 0.45300000000000001,
#   'title': b'Sabor Guajiro',
#   'year': 0},
#  {'artist': b'Loudon Wainwright III',
#   'artist_id': b'ARV1JVD1187B9AD195',
#   'danceability': 0.0,
#   'duration': 190.48444000000001,
#   'end_of_fade': 0.25800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.6610801676039384,
#   'hotttness_song': 0.51011931403303468,
#   'hotttnesss_artist': 0.44276584202895042,
#   'key': 3,
#   'key_confidence': 0.54400000000000004,
#   'latitude': 35.914630000000002,
#   'location': b'Chapel Hill, NC',
#   'longitude': -79.056610000000006,
#   'loudness': -15.663,
#   'mbid': b'3ddc1fe4-0abb-4af0-9392-e36720386842',
#   'mode': 1,
#   'mode_confidence': 0.59599999999999997,
#   'playmeid': 14418,
#   'release': b'Grown Man',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16308,
#   'seven_trackid': 315300,
#   'song_id': b'SOINBCU12A6D4F94C0',
#   'start_fade': 177.029,
#   'tempo': 102.428,
#   'time_signature': 4,
#   'time_signature_confidence': 0.496,
#   'title': b'Human Cannonball',
#   'year': 1995},
#  {'artist': b'R.L. Burnside',
#   'artist_id': b'AR7TTS41187B9B42D3',
#   'danceability': 0.0,
#   'duration': 277.78566999999998,
#   'end_of_fade': 0.23999999999999999,
#   'energy': 0.0,
#   'familiarity': 0.70118087360755066,
#   'hotttness_song': 0.48213758506501503,
#   'hotttnesss_artist': 0.46662888890168458,
#   'key': 2,
#   'key_confidence': 0.0,
#   'latitude': 34.36401,
#   'location': b'Oxford, MS',
#   'longitude': -89.518770000000004,
#   'loudness': -6.944,
#   'mbid': b'355eed00-6c40-4d33-940a-600b2597407a',
#   'mode': 1,
#   'mode_confidence': 0.0,
#   'playmeid': 26588,
#   'release': b'A Bothered Mind',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 6186,
#   'seven_trackid': 6169318,
#   'song_id': b'SOTWVQT12A58A79650',
#   'start_fade': 267.45299999999997,
#   'tempo': 89.983999999999995,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Glory Be',
#   'year': 2004},
#  {'artist': b'Stevie Ray Vaughan',
#   'artist_id': b'ART3O5Z1187B9AB043',
#   'danceability': 0.0,
#   'duration': 248.78975,
#   'end_of_fade': 0.183,
#   'energy': 0.0,
#   'familiarity': 0.7337989404362274,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.54425750572452603,
#   'key': 1,
#   'key_confidence': 0.754,
#   'latitude': 32.778149999999997,
#   'location': b'Dallas, TX',
#   'longitude': -96.795400000000001,
#   'loudness': -7.8049999999999997,
#   'mbid': b'f5426431-f490-4678-ad44-a75c71097bb4',
#   'mode': 1,
#   'mode_confidence': 0.59699999999999998,
#   'playmeid': 9729,
#   'release': b'Greatest Hits',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 48814,
#   'seven_trackid': 4659073,
#   'song_id': b'SOTSEJY12AB0180F56',
#   'start_fade': 246.19,
#   'tempo': 116.721,
#   'time_signature': 4,
#   'time_signature_confidence': 0.52200000000000002,
#   'title': b'Crossfire',
#   'year': 1992},
#  {'artist': b'John Hammond',
#   'artist_id': b'AR5U94U1187FB5CDCF',
#   'danceability': 0.0,
#   'duration': 195.31710000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.59069291794716228,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.45281783769711387,
#   'key': 7,
#   'key_confidence': 0.97999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -10.699999999999999,
#   'mbid': b'd83e599c-2d5a-44ec-b727-587e1455b1b5',
#   'mode': 1,
#   'mode_confidence': 0.753,
#   'playmeid': 7350,
#   'release': b'Bluesman',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 39546,
#   'seven_trackid': 6378564,
#   'song_id': b'SOTSETT12AB01863B8',
#   'start_fade': 187.61699999999999,
#   'tempo': 123.142,
#   'time_signature': 4,
#   'time_signature_confidence': 0.67800000000000005,
#   'title': b"I Can't Be Satisfied",
#   'year': 2002},
#  {'artist': b'Casiotone For The Painfully Alone',
#   'artist_id': b'ARRJNTE1187FB44E12',
#   'danceability': 0.0,
#   'duration': 175.72525999999999,
#   'end_of_fade': 0.73399999999999999,
#   'energy': 0.0,
#   'familiarity': 0.66532216190601845,
#   'hotttness_song': 0.78589228838835379,
#   'hotttnesss_artist': 0.39421719890100421,
#   'key': 0,
#   'key_confidence': 0.52200000000000002,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -10.93,
#   'mbid': b'73d882c7-1146-4012-a61b-a3b2c11fce2f',
#   'mode': 1,
#   'mode_confidence': 0.47399999999999998,
#   'playmeid': -1,
#   'release': b'Etiquette',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 48409,
#   'seven_trackid': 2573759,
#   'song_id': b'SOTUNMH12A6D4FA3E6',
#   'start_fade': 168.69900000000001,
#   'tempo': 141.91900000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.44500000000000001,
#   'title': b'Nashville Parthenon',
#   'year': 2006},
#  {'artist': b'Ec8or',
#   'artist_id': b'AR6IRG41187B9A4D98',
#   'danceability': 0.0,
#   'duration': 217.23383000000001,
#   'end_of_fade': 1.042,
#   'energy': 0.0,
#   'familiarity': 0.50407566993031627,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.33457736011909872,
#   'key': 10,
#   'key_confidence': 0.0050000000000000001,
#   'latitude': 52.516069999999999,
#   'location': b'Berlin, Germany',
#   'longitude': 13.37698,
#   'loudness': -9.4930000000000003,
#   'mbid': b'168e3ccd-91f5-480c-970a-b35171c71164',
#   'mode': 0,
#   'mode_confidence': 0.30499999999999999,
#   'playmeid': -1,
#   'release': b'Ec8or',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 7171,
#   'seven_trackid': 5591305,
#   'song_id': b'SOEPPKB12AB018418B',
#   'start_fade': 213.49600000000001,
#   'tempo': 95.596000000000004,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'title': b'Cocain Ducks',
#   'year': 1995},
#  {'artist': b'The New York Dolls',
#   'artist_id': b'ARS1OWB1187B99EEAD',
#   'danceability': 0.0,
#   'duration': 344.05831999999998,
#   'end_of_fade': 0.068000000000000005,
#   'energy': 0.0,
#   'familiarity': 0.71767052472855197,
#   'hotttness_song': 0.5616924111789523,
#   'hotttnesss_artist': 0.47930845933822741,
#   'key': 11,
#   'key_confidence': 0.42499999999999999,
#   'latitude': nan,
#   'location': b'New York, NY',
#   'longitude': nan,
#   'loudness': -9.2530000000000001,
#   'mbid': b'1b96b9c9-0832-40cb-9f8d-7274de3733fc',
#   'mode': 1,
#   'mode_confidence': 0.48599999999999999,
#   'playmeid': 5379,
#   'release': b'Too Much Too Soon',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 24313,
#   'seven_trackid': 770031,
#   'song_id': b'SOGKIWV12A6D4F86C4',
#   'start_fade': 335.029,
#   'tempo': 154.953,
#   'time_signature': 1,
#   'time_signature_confidence': 0.0,
#   'title': b'Human Being',
#   'year': 1974},
#  {'artist': b'Eliane Elias',
#   'artist_id': b'ARGMXQW1187FB54C34',
#   'danceability': 0.0,
#   'duration': 251.42812000000001,
#   'end_of_fade': 0.070999999999999994,
#   'energy': 0.0,
#   'familiarity': 0.66972618756614455,
#   'hotttness_song': 0.43483809026085618,
#   'hotttnesss_artist': 0.42791424698295477,
#   'key': 7,
#   'key_confidence': 0.39100000000000001,
#   'latitude': -23.56287,
#   'location': b'Sao Paulo, Brazil',
#   'longitude': -46.65466,
#   'loudness': -12.009,
#   'mbid': b'9974cbc1-6a00-4a97-8a36-e4a25bfe0293',
#   'mode': 1,
#   'mode_confidence': 0.31900000000000001,
#   'playmeid': 14229,
#   'release': b'Bossa Nova Stories',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 2800,
#   'seven_trackid': 3635000,
#   'song_id': b'SOPHYIS12AAF3B35A3',
#   'start_fade': 237.59800000000001,
#   'tempo': 86.090999999999994,
#   'time_signature': 5,
#   'time_signature_confidence': 0.55100000000000005,
#   'title': b'The More I See You',
#   'year': 2009},
#  {'artist': b'Lost Boyz',
#   'artist_id': b'AROEL1B1187B988B90',
# ...
#   'mode_confidence': 0.30099999999999999,
#   'playmeid': 24471,
#   'release': b'Never Seen The Light Of Day -Deluxe Version',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 9878,
#   'seven_trackid': 3015706,
#   'song_id': b'SOYXFLF12A6D4FBF4E',
#   'start_fade': 133.863,
#   'tempo': 152.041,
#   'time_signature': 4,
#   'time_signature_confidence': 0.36199999999999999,
#   'title': b'Misty Mountains',
#   'year': 2007},
#  {'artist': b'Donnie McClurkin',
#   'artist_id': b'ARF3HEO1187B9AF2F4',
#   'danceability': 0.0,
#   'duration': 198.58240000000001,
#   'end_of_fade': 0.32800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.6060110032472622,
#   'hotttness_song': 0.45744716708510053,
#   'hotttnesss_artist': 0.4872029945562743,
#   'key': 9,
#   'key_confidence': 0.58799999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.1289999999999996,
#   'mbid': b'1cef08dc-0429-4353-9916-9f6f421d61e9',
#   'mode': 1,
#   'mode_confidence': 0.68700000000000006,
#   'playmeid': 7072,
#   'release': b'Donnie McClurkin... Again',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 5198,
#   'seven_trackid': 5846335,
#   'song_id': b'SOTJLKO12A8AE4888B',
#   'start_fade': 191.803,
#   'tempo': 143.98599999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.55600000000000005,
#   'title': b'All I Ever Really Wanted',
#   'year': 0},
#  {'artist': b'NewFound Road',
#   'artist_id': b'ARXBXVM11E9057944C',
#   'danceability': 0.0,
#   'duration': 176.56118000000001,
#   'end_of_fade': 0.107,
#   'energy': 0.0,
#   'familiarity': 0.51850127316668726,
#   'hotttness_song': 0.25383473613223129,
#   'hotttnesss_artist': 0.38370057917998429,
#   'key': 7,
#   'key_confidence': 1.0,
#   'latitude': 40.190330000000003,
#   'location': b'Ohio',
#   'longitude': -82.669470000000004,
#   'loudness': -5.8639999999999999,
#   'mbid': b'f51617fe-32fd-4562-b3d2-9ad12cd97d92',
#   'mode': 1,
#   'mode_confidence': 0.84599999999999997,
#   'playmeid': -1,
#   'release': b'Same Old Place',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 301089,
#   'seven_trackid': 6933888,
#   'song_id': b'SOHSPMJ12AB0181C96',
#   'start_fade': 167.172,
#   'tempo': 223.34,
#   'time_signature': 4,
#   'time_signature_confidence': 0.47999999999999998,
#   'title': b'Brand New Broken Heart',
#   'year': 2009},
#  {'artist': b'Vilma Palma e Vampiros',
#   'artist_id': b'ARS26BQ1187B99466D',
#   'danceability': 0.0,
#   'duration': 210.05016000000001,
#   'end_of_fade': 0.55400000000000005,
#   'energy': 0.0,
#   'familiarity': 0.58811764966422764,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.37810696510421971,
#   'key': 7,
#   'key_confidence': 0.20300000000000001,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -6.1070000000000002,
#   'mbid': b'a03c336b-5295-4ad8-baa9-0309b47603c4',
#   'mode': 1,
#   'mode_confidence': 0.45400000000000001,
#   'playmeid': 113977,
#   'release': b'Lo Mejor De Vilma Palma',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 78095,
#   'seven_trackid': 1014822,
#   'song_id': b'SOEFZVQ12A8C138735',
#   'start_fade': 194.833,
#   'tempo': 127.803,
#   'time_signature': 4,
#   'time_signature_confidence': 0.58999999999999997,
#   'title': b'Te quiero tanto',
#   'year': 1993},
#  {'artist': b'Ray Conniff',
#   'artist_id': b'ARXZIHJ1187B9A4ED9',
#   'danceability': 0.0,
#   'duration': 191.63382999999999,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.55576499960030001,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.37651423121487881,
#   'key': 0,
#   'key_confidence': 0.14299999999999999,
#   'latitude': 41.945079999999997,
#   'location': b'Attleboro, MA',
#   'longitude': -71.281090000000006,
#   'loudness': -14.286,
#   'mbid': b'b84dfb67-c437-4ccc-b512-1073fd4612eb',
#   'mode': 1,
#   'mode_confidence': 0.39800000000000002,
#   'playmeid': 8531,
#   'release': b'The Hollywood Collection',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 54504,
#   'seven_trackid': 7855564,
#   'song_id': b'SOIDOHE12A8C135371',
#   'start_fade': 185.69,
#   'tempo': 65.852000000000004,
#   'time_signature': 4,
#   'time_signature_confidence': 0.74199999999999999,
#   'title': b'Yesterdays',
#   'year': 0},
#  {'artist': b'Nelson Ned',
#   'artist_id': b'AR6C8EJ1187FB3F473',
#   'danceability': 0.0,
#   'duration': 177.63220000000001,
#   'end_of_fade': 0.32800000000000001,
#   'energy': 0.0,
#   'familiarity': 0.49866364857789747,
#   'hotttness_song': 0.24731709912816252,
#   'hotttnesss_artist': 0.32188268994567615,
#   'key': 9,
#   'key_confidence': 0.39400000000000002,
#   'latitude': nan,
#   'location': b' Ub\xc3\xa1, Minas Gerais',
#   'longitude': nan,
#   'loudness': -12.026,
#   'mbid': b'5c70dd66-e717-4ce3-8940-9a530f492383',
#   'mode': 1,
#   'mode_confidence': 0.51400000000000001,
#   'playmeid': 66900,
#   'release': b'Selecao De Ouro Vol.2',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 17871,
#   'seven_trackid': 365121,
#   'song_id': b'SORTRUL12A6D4FA12A',
#   'start_fade': 168.62899999999999,
#   'tempo': 85.700000000000003,
#   'time_signature': 3,
#   'time_signature_confidence': 0.20699999999999999,
#   'title': b'Mi Sangre Latino',
#   'year': 0},
#  {'artist': b'Madilu System',
#   'artist_id': b'AR199MY1187B9B731E',
#   'danceability': 0.0,
#   'duration': 451.44770999999997,
#   'end_of_fade': 0.23499999999999999,
#   'energy': 0.0,
#   'familiarity': 0.42120914657330533,
#   'hotttness_song': 0.349166902124596,
#   'hotttnesss_artist': 0.29460789278647759,
#   'key': 9,
#   'key_confidence': 0.0,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -3.871,
#   'mbid': b'83f58e18-23d1-40df-818c-5d5d8c536df7',
#   'mode': 1,
#   'mode_confidence': 0.108,
#   'playmeid': -1,
#   'release': b'La Bonne Humeur',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 189121,
#   'seven_trackid': 2809287,
#   'song_id': b'SOMKRRH12A8C13C411',
#   'start_fade': 440.66800000000001,
#   'tempo': 130.126,
#   'time_signature': 5,
#   'time_signature_confidence': 0.77700000000000002,
#   'title': b'Vincent',
#   'year': 0},
#  {'artist': b'Set Your Goals',
#   'artist_id': b'ARKCYJV1187FB392E9',
#   'danceability': 0.0,
#   'duration': 204.40771000000001,
#   'end_of_fade': 2.1480000000000001,
#   'energy': 0.0,
#   'familiarity': 0.82391008735858451,
#   'hotttness_song': 0.71839133028994295,
#   'hotttnesss_artist': 0.54974965158743905,
#   'key': 3,
#   'key_confidence': 0.124,
#   'latitude': nan,
#   'location': b'San Francisco, CA',
#   'longitude': nan,
#   'loudness': -2.1920000000000002,
#   'mbid': b'03d8f83e-a647-4bde-968a-189c0f147783',
#   'mode': 1,
#   'mode_confidence': 0.29899999999999999,
#   'playmeid': 33269,
#   'release': b'This Will Be The Death Of Us',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 66284,
#   'seven_trackid': 5819356,
#   'song_id': b'SOSVWIE12A8C143BD4',
#   'start_fade': 192.78899999999999,
#   'tempo': 194.53200000000001,
#   'time_signature': 3,
#   'time_signature_confidence': 0.17299999999999999,
#   'title': b'the fallen...',
#   'year': 2009},
#  {'artist': b'The High Strung',
#   'artist_id': b'ARTE6AQ1187B9B2826',
#   'danceability': 0.0,
#   'duration': 153.73016000000001,
#   'end_of_fade': 0.0,
#   'energy': 0.0,
#   'familiarity': 0.5999446698556915,
#   'hotttness_song': 0.37952332442218817,
#   'hotttnesss_artist': 0.3968002189789247,
#   'key': 9,
#   'key_confidence': 0.623,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -2.6789999999999998,
#   'mbid': b'2b418029-92e6-4aa6-8099-f796fffb3023',
#   'mode': 1,
#   'mode_confidence': 0.63100000000000001,
#   'playmeid': 141898,
#   'release': b'Ode to the Inverse of the Dude',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 124455,
#   'seven_trackid': 4694767,
#   'song_id': b'SOBXEJI12A58A79725',
#   'start_fade': 140.72999999999999,
#   'tempo': 95.109999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.54200000000000004,
#   'title': b'The Lifestyle That Got Away',
#   'year': 2009},
#  {'artist': b'Lost Boyz',
#   'artist_id': b'AROEL1B1187B988B90',
#   'danceability': 0.0,
#   'duration': 243.53914,
#   'end_of_fade': 0.25900000000000001,
#   'energy': 0.0,
#   'familiarity': 0.56974115228189715,
#   'hotttness_song': 0.4081108835105221,
#   'hotttnesss_artist': 0.41224060053560735,
#   'key': 9,
#   'key_confidence': 0.16500000000000001,
#   'latitude': nan,
#   'location': b'South Jamaica, Queens',
#   'longitude': nan,
#   'loudness': -9.7249999999999996,
#   'mbid': b'8b70d4d9-b3d3-4a99-8a95-96ee59f12140',
#   'mode': 1,
#   'mode_confidence': 0.40600000000000003,
#   'playmeid': -1,
#   'release': b'Love_ Peace & Nappiness',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 10275,
#   'seven_trackid': 151794,
#   'song_id': b'SOOTDEC12A6701D0FF',
#   'start_fade': 235.91499999999999,
#   'tempo': 93.174000000000007,
#   'time_signature': 4,
#   'time_signature_confidence': 0.81599999999999995,
#   'title': b'Get Your Hustle On',
#   'year': 1997},
#  {'artist': b'Nic Endo',
#   'artist_id': b'ARQL2SZ1187B99244B',
#   'danceability': 0.0,
#   'duration': 388.0224,
#   'end_of_fade': 2.125,
#   'energy': 0.0,
#   'familiarity': 0.56707373018965423,
#   'hotttness_song': 0.29987748827397781,
#   'hotttnesss_artist': 0.43115980455370512,
#   'key': 3,
#   'key_confidence': 0.33100000000000002,
#   'latitude': 31.168900000000001,
#   'location': b'Texas',
#   'longitude': -100.07715,
#   'loudness': -2.9279999999999999,
#   'mbid': b'433cebcc-b3b3-4516-99ae-63aa991b1401',
#   'mode': 1,
#   'mode_confidence': 0.439,
#   'playmeid': -1,
#   'release': b'White Heat',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 7201,
#   'seven_trackid': 5592299,
#   'song_id': b'SOCAKKR12AB01866C9',
#   'start_fade': 383.94200000000001,
#   'tempo': 88.400000000000006,
#   'time_signature': 5,
#   'time_signature_confidence': 0.54000000000000004,
#   'title': b'Future Prospects',
#   'year': 1998},
#  {'artist': b'Dropkick Murphys',
#   'artist_id': b'ARD2NDU1187B99B615',
#   'danceability': 0.0,
#   'duration': 229.51138,
#   'end_of_fade': 0.13700000000000001,
#   'energy': 0.0,
#   'familiarity': 0.79309437008166128,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.5684918154445614,
#   'key': 9,
#   'key_confidence': 0.90900000000000003,
#   'latitude': nan,
#   'location': b'Boston, MA',
#   'longitude': nan,
#   'loudness': -3.9180000000000001,
#   'mbid': b'e8374874-4178-4869-b92e-fef6bf30dc04',
#   'mode': 1,
#   'mode_confidence': 0.39600000000000002,
#   'playmeid': -1,
#   'release': b'Do Or Die',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 13626,
#   'seven_trackid': 1081263,
#   'song_id': b'SOJWGEI12A8C13CA8F',
#   'start_fade': 223.55600000000001,
#   'tempo': 168.21000000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.621,
#   'title': b'Skinhead on the MBTA (Album Version)',
#   'year': 1997},
#  {'artist': b'Kim Wilson',
#   'artist_id': b'ARSAJKR1187FB4C5DC',
#   'danceability': 0.0,
#   'duration': 286.51056999999997,
#   'end_of_fade': 0.432,
#   'energy': 0.0,
#   'familiarity': 0.45981016275133263,
#   'hotttness_song': 0.26695518627553855,
#   'hotttnesss_artist': 0.32899785889428945,
#   'key': 9,
#   'key_confidence': 0.57699999999999996,
#   'latitude': 42.331679999999999,
#   'location': b'Detroit, MI',
#   'longitude': -83.047920000000005,
#   'loudness': -8.0960000000000001,
#   'mbid': b'd30137de-a6bc-4330-bbbb-743e3551e892',
#   'mode': 1,
#   'mode_confidence': 0.64100000000000001,
#   'playmeid': 93802,
#   'release': b"Lookin' For Trouble!",
#   'sample_rate_analysis': 22050,
#   'seven_digital': 126013,
#   'seven_trackid': 2613430,
#   'song_id': b'SOINZJI12A8C1337A1',
#   'start_fade': 281.05399999999997,
#   'tempo': 119.64400000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Love Attack',
#   'year': 2003},
#  {'artist': b'Daath',
#   'artist_id': b'AR08GQF1187B98E316',
#   'danceability': 0.0,
#   'duration': 248.81586999999999,
#   'end_of_fade': 0.10199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.47396333320767403,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.35070665990043637,
#   'key': 4,
#   'key_confidence': 0.059999999999999998,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -3.9609999999999999,
#   'mbid': b'9661a587-fdb1-461d-abde-f6280acbde6b',
#   'mode': 0,
#   'mode_confidence': 0.36399999999999999,
#   'playmeid': 7382,
#   'release': b'The Hinderers',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 54581,
#   'seven_trackid': 1432650,
#   'song_id': b'SOBTQGV12A8AE496ED',
#   'start_fade': 248.816,
#   'tempo': 150.16300000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.0,
#   'title': b'Above Lucium (LP Version)',
#   'year': 2006},
#  {'artist': b'Suicidal Tendencies',
#   'artist_id': b'ARNDB1X1187B990AA0',
#   'danceability': 0.0,
#   'duration': 125.90975,
#   'end_of_fade': 0.30199999999999999,
#   'energy': 0.0,
#   'familiarity': 0.73667741334063197,
#   'hotttness_song': 0.57865818775697131,
#   'hotttnesss_artist': 0.52618255634684785,
#   'key': 11,
#   'key_confidence': 0.76800000000000002,
#   'latitude': 34.053489999999996,
#   'location': b'Venice, CA',
#   'longitude': -118.24532000000001,
#   'loudness': -9.9600000000000009,
#   'mbid': b'e9e2a634-984f-4c10-bf7b-7970179e1ef1',
#   'mode': 0,
#   'mode_confidence': 0.68100000000000005,
#   'playmeid': 12797,
#   'release': b'Join The Army',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16331,
#   'seven_trackid': 1108714,
#   'song_id': b'SOIMSRQ12A6D4F648F',
#   'start_fade': 120.79600000000001,
#   'tempo': 186.15899999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.27800000000000002,
#   'title': b'Human Guinea Pig',
#   'year': 1987},
#  {'artist': b'Bobby Vee',
#   'artist_id': b'ARBUHDB1187FB3E72C',
#   'danceability': 0.0,
#   'duration': 256.28689000000003,
#   'end_of_fade': 0.17699999999999999,
#   'energy': 0.0,
#   'familiarity': 0.62313043687860192,
#   'hotttness_song': 0.0,
#   'hotttnesss_artist': 0.39524762318141715,
#   'key': 10,
#   'key_confidence': 0.95899999999999996,
#   'latitude': 46.875909999999998,
#   'location': b'Fargo, ND',
#   'longitude': -96.781760000000006,
#   'loudness': -10.872,
#   'mbid': b'97ebb1b4-1d9c-4303-bb60-074c993e2d53',
#   'mode': 1,
#   'mode_confidence': 0.72499999999999998,
#   'playmeid': 2595,
#   'release': b'Just Today',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 16435,
#   'seven_trackid': 5147694,
#   'song_id': b'SOMNRNZ12A8C144C90',
#   'start_fade': 243.93700000000001,
#   'tempo': 132.10900000000001,
#   'time_signature': 4,
#   'time_signature_confidence': 0.79200000000000004,
#   'title': b'Wink Of An Eye',
#   'year': 0},
#  {'artist': b'Bill & Gloria Gaither',
#   'artist_id': b'ARKC83D1187B9AB367',
#   'danceability': 0.0,
#   'duration': 181.15872999999999,
#   'end_of_fade': 0.12,
#   'energy': 0.0,
#   'familiarity': 0.49392614468639018,
#   'hotttness_song': 0.27077599894632748,
#   'hotttnesss_artist': 0.31962677591740224,
#   'key': 6,
#   'key_confidence': 0.34499999999999997,
#   'latitude': nan,
#   'location': b'',
#   'longitude': nan,
#   'loudness': -13.991,
#   'mbid': b'c55b50e3-5f4e-461d-bf29-79d2c2c364c5',
#   'mode': 0,
#   'mode_confidence': 0.46300000000000002,
#   'playmeid': 62535,
#   'release': b'Israel Homecoming',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 15749,
#   'seven_trackid': 672086,
#   'song_id': b'SOQUGOE12A6D4FA6FF',
#   'start_fade': 173.91200000000001,
#   'tempo': 139.22999999999999,
#   'time_signature': 4,
#   'time_signature_confidence': 0.57799999999999996,
#   'title': b'Awesome God',
#   'year': 0},
#  {'artist': b'Jennifer Brown',
#   'artist_id': b'ARXLOGT1187FB45068',
#   'danceability': 0.0,
#   'duration': 239.07220000000001,
#   'end_of_fade': 0.45900000000000002,
#   'energy': 0.0,
#   'familiarity': 0.49348647312851901,
#   'hotttness_song': nan,
#   'hotttnesss_artist': 0.38631213060016512,
#   'key': 8,
#   'key_confidence': 0.51200000000000001,
#   'latitude': 34.197670000000002,
#   'location': b'PLAINVIEW, Texas',
#   'longitude': -101.69814,
#   'loudness': -8.2460000000000004,
#   'mbid': b'288af6c6-e5b7-4b2b-8f30-d164a05fa6a3',
#   'mode': 1,
#   'mode_confidence': 0.65500000000000003,
#   'playmeid': -1,
#   'release': b'Vera',
#   'sample_rate_analysis': 22050,
#   'seven_digital': 106363,
#   'seven_trackid': 3412385,
#   'song_id': b'SONYXMF12A8C13EB31',
#   'start_fade': 224.25299999999999,
#   'tempo': 90.915000000000006,
#   'time_signature': 4,
#   'time_signature_confidence': 0.496,
#   'title': b'Naked',
#   'year': 1998},
#  ...]

# %%
with open('dataframes/df1.pkl', 'rb') as picklefile:
	df1 = pickle.load(picklefile)
df1.head()
# Out:
#                                    artist              artist_id  \
# 0                             b'Mastodon'  b'ARMQHX71187B9890D3'
# 1                               b'Casual'  b'ARD7TVE1187B99BFB1'
# 2                         b'The Box Tops'  b'ARMJAGH1187FB546F3'
# 3                     b'Sonora Santanera'  b'ARKRRTF1187B9984DA'
# 4                             b'Adam Ant'  b'AR7G5I41187FB4CE6C'
# 5                                  b'Gob'  b'ARXR32B1187FB57099'
# 6                b'Jeff And Sheri Easter'  b'ARKFYS91187B98E58F'
# 7                              b'Rated R'  b'ARD0S291187B9B7BF5'
# 8                b'Tweeterfriendly Music'  b'AR10USD1187B99F3F1'
# 9                     b'Planet P Project'  b'AR8ZCNI1187B9A069B'
# 10                                 b'Clp'  b'ARNTLGG11E2835DDB9'
# 11                        b'JennyAnyKind'  b'ARGSJW91187B9B1D6B'
# 12                        b'Wayne Watson'  b'ARC43071187B990240'
# 13                           b'Andy Andy'  b'ARL7K851187B99ACD2'
# 14                           b'Bob Azzam'  b'ARHHO3O1187B989413'
# 15                       b'Lionel Richie'  b'ARIK43K1187B9AE54C'
# 16                          b'Blue Rodeo'  b'ARD842G1187B997376'
# 17                     b'Richard Souther'  b'ARIG6O41187B988BDD'
# 18                       b'Faiz Ali Faiz'  b'AR1ZHYZ1187FB3C717'
# 19                               b'Tesla'  b'ARYKCQI1187FB3B18F'
# 20                           b'lextrical'  b'ARNPAGP1241B9C7FD4'
# 21                        b'Jimmy Wakely'  b'ARQGYP71187FB44566'
# 22                        b'Alice Stuart'  b'ARI3BMM1187FB4255E'
# 23                               b'Elena'  b'AR5KOSW1187FB35FF4'
# 24           b'The Dillinger Escape Plan'  b'ARMAC4T1187FB3FA4C'
# 25                        b'SUE THOMPSON'  b'AR47JEX1187B995D81'
# 26                      b'Five Bolt Main'  b'ARGIWFO1187B9B55B7'
# 27                                 b'Clp'  b'ARNTLGG11E2835DDB9'
# 28                          b'Tim Wilson'  b'ARDNS031187B9924F0'
# 29                         b'Willie Bobo'  b'AROUOZZ1187B9ABE51'
# ...                                   ...                    ...
# 9971                      b'Dinosaur Jr.'  b'AR9YWMS1187FB43A34'
# 9972                         b'Sin Plomo'  b'ARDNMNC11F4C842FDE'
# 9973                     b'Lloyd Spiegel'  b'ARDDYFH11F4C83DD58'
# 9974                   b'The Sex Pistols'  b'ARD3LXU1187B9ABFC5'
# 9975   b'Toni Braxton Featuring Babyface'  b'ARAEX7Y1187FB42D36'
# 9976                        b'Cal Tjader'  b'AR9ST641187B99B4DE'
# 9977                             b'Aiden'  b'ARJ8PZJ1187B99314F'
# 9978                       b'Winterlight'  b'ARJEFGV1241B9C6F79'
# 9979                        b'themselves'  b'ARNVM131187B990D2B'
# 9980                       b'Ivan Parker'  b'AR9UT8H1187B9AF504'
# 9981                           b'Daara J'  b'ARKZNO81187FB37FBA'
# 9982                   b'New Found Glory'  b'ARH9HS41187FB5BC6F'
# 9983          b'Mar\xc3\xada Elena Walsh'  b'ARFILWJ1187B9ADDBF'
# 9984                    b'Mindy McCready'  b'ARZL6CE1187FB3F264'
# 9985                      b'Joy Division'  b'ARKZXSQ1187B9AC9F3'
# 9986                     b'Don Francisco'  b'ARLQ5EV1187FB4491D'
# 9987                           b'Kaskaad'  b'ARMATAK1264D13AC27'
# 9988                  b'Chantal Chamandy'  b'AR5S26K1187B9A3141'
# 9989            b'Mouth Of The Architect'  b'AR0ILWV1187FB47CAA'
# 9990                     b'It Dies Today'  b'ARJGQJD1187B997A00'
# 9991                    b'Diamanda Galas'  b'ARUUP4L1187B9B72EB'
# 9992                  b'David Arkenstone'  b'ARI4S0E1187B9B06C0'
# 9993                  b'Mario Rosenstock'  b'AROIHOI122988FEB8E'
# 9994                     b'Grandpa Jones'  b'ARQ91R31187FB38A88'
# 9995              b'Blind Willie Johnson'  b'ARDK0551187FB5AC48'
# 9996                         b'Moonspell'  b'AR4C6V01187FB3BAF4'
# 9997                    b'Danny Williams'  b'AR9JLBU1187B9AAEC4'
# 9998                     b'Winston Reedy'  b'ARS1DCR1187B9A4A56'
# 9999          b'Myrick "Freeze" Guillory'  b'ARAGMIV11F4C843F78'
# 10000              b'Seventh Day Slumber'  b'ARYXOV81187B99831D'
#
#        danceability   duration  end_of_fade  energy  familiarity  \
# 0               0.0  280.21506        0.238     0.0     0.780462
# 1               0.0  218.93179        0.247     0.0     0.581794
# 2               0.0  148.03546        0.148     0.0     0.630630
# 3               0.0  177.47546        0.282     0.0     0.487357
# 4               0.0  233.40363        0.000     0.0     0.630382
# 5               0.0  209.60608        0.066     0.0     0.651046
# 6               0.0  267.70240        2.264     0.0     0.535293
# 7               0.0  114.78159        0.096     0.0     0.556496
# 8               0.0  189.57016        0.319     0.0     0.801136
# 9               0.0  269.81832        5.300     0.0     0.426668
# 10              0.0  266.39628        0.084     0.0     0.550514
# 11              0.0  218.77506        2.125     0.0     0.360031
# 12              0.0  245.21098        0.357     0.0     0.545159
# 13              0.0  226.35057        0.000     0.0     0.577509
# 14              0.0  191.84281        0.380     0.0     0.085512
# 15              0.0  307.38240        0.612     0.0     0.776676
# 16              0.0  491.12771        0.000     0.0     0.636424
# 17              0.0  228.59710        0.223     0.0     0.419943
# 18              0.0  599.24853        1.193     0.0     0.363281
# 19              0.0  290.29832        0.145     0.0     0.707200
# 20              0.0  165.69424        0.162     0.0     0.320314
# 21              0.0  151.84934        2.827     0.0     0.394139
# 22              0.0  220.78649        0.206     0.0     0.489816
# 23              0.0  269.58322        0.000     0.0     0.677420
# 24              0.0  207.77751        0.061     0.0     0.839963
# 25              0.0  124.86485        0.000     0.0     0.435416
# 26              0.0  225.09669        0.000     0.0     0.609064
# 27              0.0  338.31138        0.000     0.0     0.550514
# 28              0.0  186.48771        1.083     0.0     0.459797
# 29              0.0  168.25424        0.200     0.0     0.588827
# ...             ...        ...          ...     ...          ...
# 9971            0.0  198.53016        0.374     0.0     0.749797
# 9972            0.0  444.49914        3.947     0.0     0.461173
# 9973            0.0  188.70812        0.000     0.0     0.461273
# 9974            0.0  176.58730        0.165     0.0     0.731184
# 9975            0.0  240.61342        0.311     0.0     0.737973
# 9976            0.0  199.75791        0.328     0.0     0.624200
# 9977            0.0  241.03138        0.000     0.0     0.773491
# 9978            0.0  328.67220        0.000     0.0     0.467138
# 9979            0.0  271.43791        0.094     0.0     0.628274
# 9980            0.0  207.90812        2.113     0.0     0.384720
# 9981            0.0  261.61587        3.030     0.0     0.529020
# 9982            0.0  208.27383        0.113     0.0     0.891854
# 9983            0.0  150.09914        0.000     0.0     0.341514
# 9984            0.0  231.83628        0.000     0.0     0.679292
# 9985            0.0  141.08689        0.000     0.0     0.764287
# 9986            0.0  311.22240        3.646     0.0     0.508059
# 9987            0.0  414.90240        0.000     0.0     0.383594
# 9988            0.0  256.15628        0.368     0.0     0.650896
# 9989            0.0  475.21914        0.000     0.0     0.582035
# 9990            0.0  179.40853        0.000     0.0     0.772230
# 9991            0.0  162.95138        0.442     0.0     0.598237
# 9992            0.0  314.59220        3.895     0.0     0.639396
# 9993            0.0  187.14077        0.311     0.0     0.334543
# 9994            0.0  141.73995        0.491     0.0     0.450646
# 9995            0.0  172.25098        0.097     0.0     0.607327
# 9996            0.0  386.19383        0.177     0.0     0.722571
# 9997            0.0  168.01914        0.403     0.0     0.511663
# 9998            0.0  193.72363        0.173     0.0     0.433508
# 9999            0.0  300.82567        0.000     0.0     0.334457
# 10000           0.0  209.73669        0.125     0.0     0.609182
#
#        hotttness_song  hotttnesss_artist  key  ...   sample_rate_analysis  \
# 0            0.597641           0.574275    5  ...                  22050
# 1            0.602120           0.401998    1  ...                  22050
# 2                 NaN           0.417500    6  ...                  22050
# 3                 NaN           0.343428    8  ...                  22050
# 4                 NaN           0.454231    0  ...                  22050
# 5            0.604501           0.401724    2  ...                  22050
# 6                 NaN           0.385471    5  ...                  22050
# 7                 NaN           0.261941    1  ...                  22050
# 8                 NaN           0.605507    4  ...                  22050
# 9            0.265861           0.332276    4  ...                  22050
# 10                NaN           0.422706    7  ...                  22050
# 11           0.000000           0.296269    5  ...                  22050
# 12           0.265861           0.351556    7  ...                  22050
# 13           0.000000           0.379482    9  ...                  22050
# 14           0.000000           0.251937   10  ...                  22050
# 15                NaN           0.553072    3  ...                  22050
# 16           0.405116           0.447935    7  ...                  22050
# 17           0.334707           0.330806    8  ...                  22050
# 18                NaN           0.306676    6  ...                  22050
# 19           0.684136           0.513463    7  ...                  22050
# 20           0.000000           0.000000    7  ...                  22050
# 21                NaN           0.291540    1  ...                  22050
# 22           0.000000           0.328553   11  ...                  22050
# 23           0.313562           0.378255    2  ...                  22050
# 24           0.666528           0.541889    7  ...                  22050
# 25           0.495294           0.306242   10  ...                  22050
# 26           0.375984           0.363651    7  ...                  22050
# 27                NaN           0.422706    6  ...                  22050
# 28                NaN           0.349913    5  ...                  22050
# 29                NaN           0.379671    8  ...                  22050
# ...               ...                ...  ...  ...                    ...
# 9971         0.587427           0.551552    0  ...                  22050
# 9972              NaN           0.294037    7  ...                  22050
# 9973              NaN           0.265094    9  ...                  22050
# 9974              NaN           0.549204   11  ...                  22050
# 9975         0.319566           0.555969   10  ...                  22050
# 9976         0.405116           0.369077    9  ...                  22050
# 9977         0.472121           0.500459    7  ...                  22050
# 9978         0.000000           0.308486    0  ...                  22050
# 9979         0.428702           0.428835    1  ...                  22050
# 9980         0.278598           0.311097    0  ...                  22050
# 9981         0.319566           0.300735    0  ...                  22050
# 9982         0.663194           0.548228    4  ...                  22050
# 9983              NaN           0.257063    0  ...                  22050
# 9984              NaN           0.431883   10  ...                  22050
# 9985              NaN           0.576295    2  ...                  22050
# 9986         0.000000           0.372299    0  ...                  22050
# 9987              NaN           0.220210    4  ...                  22050
# 9988              NaN           0.315026   11  ...                  22050
# 9989         0.690971           0.469056    3  ...                  22050
# 9990              NaN           0.511577   11  ...                  22050
# 9991         0.323112           0.363688    5  ...                  22050
# 9992         0.360371           0.430942    9  ...                  22050
# 9993              NaN           0.049034    7  ...                  22050
# 9994         0.000000           0.331535    2  ...                  22050
# 9995              NaN           0.401145    0  ...                  22050
# 9996         0.594080           0.499826    7  ...                  22050
# 9997         0.334707           0.409779    8  ...                  22050
# 9998              NaN           0.289903    1  ...                  22050
# 9999         0.000000           0.216829    0  ...                  22050
# 10000        0.780312           0.509243    2  ...                  22050
#
#        seven_digital seven_trackid                song_id  start_fade  \
# 0              29785       2442524  b'SOVLGJY12A8C13FBED'     275.528
# 1             165270       3401791  b'SOMZWCG12A8C13C480'     218.932
# 2               1998       3400270  b'SOCIWDW12A8C13D406'     137.915
# 3             290021       5703798  b'SOXVLOJ12AB0189215'     172.304
# 4              19072       3226795  b'SONHOTT12A8C13493C'     217.124
# 5              30973       6795666  b'SOFSOCN12A8C143F5D'     198.699
# 6             432935        444964  b'SOYMRWW12A6D4FAB14'     254.270
# 7              17970        276593  b'SOMJBYD12A6D4F8557'     114.782
# 8              21128         90004  b'SOHKNRJ12A6701D1F8'     181.023
# 9             276891       3996579  b'SOIAZJW12AB01853F1'     258.990
# 10            242273       7684249  b'SOUDSGM12AC9618304'     261.747
# 11             60488       5967937  b'SOQHXMF12AB0182363'     207.012
# 12              4923       1735859  b'SOKEJEJ12A8C13E0D0'     227.480
# 13             88523       6381162  b'SOMUYGI12AB0188633'     221.553
# 14            327171       9014963  b'SORAMLE12AB017C8B0'     188.424
# 15               237        276438  b'SOBONFF12A6D4F84D8'     296.658
# 16              3950       1399936  b'SOHUOAP12A8AE488E9'     486.034
# 17             24687       1560940  b'SOUQQEA12A8C134B1B'     217.426
# 18            248913       5916675  b'SOILPQQ12AB017E82A'     591.999
# 19              1396       4143071  b'SOXLBJT12A8C140925'     285.605
# 20            399889       5991843  b'SOZVMJI12AB01808AF'     157.391
# 21             34818       6721979  b'SOWTBJW12AC468AC6E'     146.199
# 22            185559       3006504  b'SOBEBDG12A58A76D60'     207.656
# 23             69720       4292004  b'SOZCTXZ12AB0182364'     256.168
# 24             82239       2439720  b'SOBBUGU12A8C13E95D'     204.696
# 25             36525       7232396  b'SOBLGCN12AB0183212'     115.740
# 26             14773        488005  b'SOPSWQW12A6D4F8781'     225.097
# 27            242273       7448953  b'SOZQDIU12A58A7BCF6'     338.311
# 28             14504       1699837  b'SONYPOM12A8C13B2D7'     175.467
# 29             15815        618725  b'SOBZBAZ12A6D4F8742'     161.890
# ...              ...           ...                    ...         ...
# 9971            4837       2787322  b'SOOAMWT12A8C13B479'     189.980
# 9972           99734       5305359  b'SONAEGX12A8C141C53'     438.480
# 9973          268793       3868509  b'SOJYYHN12AB0182966'     184.953
# 9974             414       6882960  b'SOLQETH12AB0181E42'     168.443
# 9975           40884       3348356  b'SOIRKJL12A8C13A2AA'     227.149
# 9976           11300       3511537  b'SOASHZJ12A8C1426D8'     195.146
# 9977           21129       8566058  b'SOYYFNE12AB018A96D'     236.280
# 9978          442912       7780632  b'SOHCFNL12A8C140C2E'     308.407
# 9979          172369       2612283  b'SOLYUTF12A8C133225'     267.726
# 9980           15590       2747485  b'SOVWTKI12A58A789B6'     200.446
# 9981           15184        223904  b'SOEEPYY12A58A7B1C8'     255.303
# 9982              98       4457572  b'SOPHMRL12AB017E87B'     191.280
# 9983          455229       5646127  b'SOQEKJO12AB0188E78'     138.896
# 9984            2173       9045758  b'SOPHKAI12AB018873D'     215.789
# 9985            5633       2648266  b'SOLHMRA12A8C13234A'     136.115
# 9986           49962        671450  b'SOQUGNH12A6D4FBB0E'     295.044
# 9987          274928       3971492  b'SOHWHZJ12A58A79FA8'     408.596
# 9988           11490       5235231  b'SOOWVUN12AB0185435'     249.649
# 9989          356998       8640942  b'SOQSJJL12AC46874BC'     455.593
# 9990           36609       5322779  b'SOFOBSK12A8C1447C4'     179.409
# 9991           11354       1834226  b'SOILDRV12A8C13EB77'     154.024
# 9992             960       1572055  b'SOBUUYV12A58A7DA27'     296.153
# 9993           15464       7061099  b'SOJARSR12AB0184939'     182.671
# 9994           39299       8416790  b'SOUWMIW12AB0184748'     136.615
# 9995            8585       6630898  b'SOVMTAW12A8C13B071'     167.184
# 9996           52613       7677054  b'SOLXXPY12A67ADABA0'     386.194
# 9997            7247        442366  b'SOAYONI12A6D4F85C8'     163.463
# 9998            7562       3884209  b'SOJZLAJ12AB017E8A2'     186.015
# 9999           68313        904098  b'SORZSCJ12A8C132446'     300.826
# 10000          39252        670250  b'SOFAOMI12A6D4FA2D8'     193.167
#
#          tempo  time_signature  time_signature_confidence  \
# 0      173.205               5                      0.120
# 1       92.198               4                      0.778
# 2      121.274               4                      0.384
# 3      100.070               1                      0.000
# 4      119.293               4                      0.000
# 5      129.738               4                      0.562
# 6      147.782               3                      0.454
# 7      111.787               1                      0.000
# 8      101.430               3                      0.408
# 9       86.643               4                      0.487
# 10     114.041               4                      0.878
# 11     146.765               1                      0.000
# 12     117.975               4                      0.835
# 13     130.040               4                      0.000
# 14     137.334               1                      0.319
# 15     125.197               3                      0.211
# 16     119.826               4                      0.756
# 17     127.756               5                      0.579
# 18      99.273               4                      0.158
# 19     150.062               4                      0.931
# 20     138.331               4                      0.127
# 21      86.186               3                      0.929
# 22     110.382               1                      0.192
# 23     111.874               4                      1.000
# 24     166.862               4                      0.000
# 25     137.522               4                      0.000
# 26     164.672               1                      0.000
# 27     125.006               4                      1.000
# 28      90.022               1                      0.971
# 29     127.025               4                      0.792
# ...        ...             ...                        ...
# 9971   185.452               1                      0.000
# 9972   127.955               4                      0.000
# 9973   113.397               4                      0.948
# 9974    89.607               1                      0.000
# 9975   103.832               4                      0.986
# 9976   143.764               1                      0.137
# 9977   125.653               4                      1.000
# 9978    99.998               4                      1.000
# 9979   167.885               4                      0.465
# 9980    91.964               4                      0.944
# 9981    91.005               4                      1.000
# 9982   192.070               4                      0.937
# 9983   131.552               3                      1.000
# 9984   100.881               4                      1.000
# 9985   150.040               4                      1.000
# 9986    68.537               1                      0.000
# 9987    87.507               4                      1.000
# 9988    84.960               4                      0.380
# 9989   124.562               3                      0.989
# 9990    98.377               3                      0.991
# 9991   162.133               4                      0.668
# 9992   141.975               4                      0.659
# 9993    90.050               4                      0.433
# 9994   119.271               4                      0.150
# 9995    95.677               1                      0.000
# 9996   140.185               4                      0.099
# 9997    77.072               3                      0.597
# 9998   118.123               4                      0.205
# 9999   137.663               4                      0.000
# 10000  150.575               4                      0.317
#
#                                                    title  year
# 0                                   b'Deep Sea Creature'  2001
# 1                                    b"I Didn't Mean To"     0
# 2                                           b'Soul Deep'  1969
# 3                                     b'Amor De Cabaret'     0
# 4                                     b'Something Girls'  1982
# 5                                      b'Face the Ashes'  2007
# 6         b'The Moon And I (Ordinary Day Album Version)'     0
# 7                               b'Keepin It Real (Skit)'     0
# 8                                        b'Drop of Rain'     0
# 9                                          b'Pink World'  1984
# 10                  b'Insatiable (Instrumental Version)'     0
# 11                                    b'Young Boy Blues'     0
# 12                           b'The Urgency (LP Version)'     0
# 13                                           b'La Culpa'     0
# 14                                     b'Auguri Cha Cha'     0
# 15                            b'Tonight Will Be Alright'  1986
# 16                                           b'Floating'  1987
# 17                                          b'High Tide'     0
# 18                               b'Sohna Nee Sohna Data'     0
# 19                                  b'Caught In A Dream'  2004
# 20                                    b'Synthetic Dream'     0
# 21                         b'Broken-Down Merry-Go-Round'     0
# 22                                       b'Kassie Jones'     0
# 23                                     b'Setanta matins'     0
# 24                    b'Setting Fire to Sleeping Giants'  2004
# 25                     b'James (Hold The Ladder Steady)'  1985
# 26                              b'Made Like This (Live)'     0
# 27                                  b'Superconfidential'     0
# 28     b'I Think My Wife Is Running Around On Me (Tac...  2005
# 29                                     b'Spanish Grease'  1997
# ...                                                  ...   ...
# 9971                                    b'Does It Float'  1985
# 9972                       b"Why can't we live together"     0
# 9973                                        b'The Storm'     0
# 9974                b'My Way (Alternate Studio Version)'     0
# 9975                                  b'Give U My Heart'  2003
# 9976                                 b'Along Comes Mary'     0
# 9977                              b'Die Romantic [Live]'     0
# 9978                                         b'Daybreak'     0
# 9979                                 b'Crayon Sharpener'  2003
# 9980                              b'Then He Said_ "Sing'     0
# 9981                                     b'Le Precipice'     0
# 9982                      b"Don't Let Her Pull You Down"  2009
# 9983                                  b'La Mona Jacinta'  2000
# 9984                              b'Ten Thousand Angels'  1996
# 9985                                   b'Leaders Of Men'  1978
# 9986                         b'Overture (Genesis & Job)'     0
# 9987                                      b'Mohawk Hunt'     0
# 9988                                          b'Zindegi'     0
# 9989                          b'Harboring An Apparition'  2006
# 9990                      b'One the road (to Damnation)'  2006
# 9991                           b'Dark End Of The Street'     0
# 9992                              b'The Forgotten Lands'  1996
# 9993                      b'Munster Song (Best of 2009)'     0
# 9994                                    b'Down In Dixie'     0
# 9995                           b"God Don't Never Change"  1989
# 9996                                   b'The Hanged Man'  1998
# 9997                 b'The Wonderful World Of The Young'  1998
# 9998                                  b'Sentimental Man'     0
# 9999                                b'Zydeco In D-Minor'     0
# 10000                                  b'Shattered Life'  2005
#
# [10001 rows x 30 columns]

# %%
def text_clean(x):
    try:
        x = x.decode('utf-8')
    except:
        None
    return x

df1 = df1.applymap(text_clean)

# %%
with open('dataframes/msd_clean.pkl', 'wb') as picklefile:
    pickle.dump(df1, picklefile)
